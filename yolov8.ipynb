# %%
# !nvidia-smi
# Out:
# Tue Mar 12 10:32:13 2024
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 516.01       Driver Version: 516.01       CUDA Version: 11.7     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ... WDDM  | 00000000:01:00.0  On |                  N/A |
# | N/A   57C    P8    12W /  N/A |    232MiB /  8192MiB |      1%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
pip show torch torchvision torchaudio
# Out:
# Name: torch
# Version: 2.1.2+cu121
# Summary: Tensors and Dynamic neural networks in Python with strong GPU acceleration
# Home-page: https://pytorch.org/
# Author: PyTorch Team
# Author-email: packages@pytorch.org
# License: BSD-3
# Location: c:\users\dr. justin\anaconda3\envs\yolov8\lib\site-packages
# Requires: filelock, fsspec, jinja2, networkx, sympy, typing-extensions
# Required-by: thop, torchaudio, torchvision, ultralytics
# ---
# Name: torchvision
# Version: 0.16.2+cu121
# Summary: image and video datasets and models for torch deep learning
# Home-page: https://github.com/pytorch/vision
# Author: PyTorch Core Team
# Author-email: soumith@pytorch.org
# License: BSD
# Location: c:\users\dr. justin\anaconda3\envs\yolov8\lib\site-packages
# Requires: numpy, pillow, requests, torch
# Required-by: ultralytics
# ---
# Name: torchaudio
# Version: 2.1.2+cu121
# Summary: An audio package for PyTorch
# Home-page: https://github.com/pytorch/audio
# Author: Soumith Chintala, David Pollack, Sean Naren, Peter Goldsborough, Moto Hira, Caroline Chen, Jeff Hwang, Zhaoheng Ni, Xiaohui Zhang
# Author-email: soumith@pytorch.org
# License:
# Location: c:\users\dr. justin\anaconda3\envs\yolov8\lib\site-packages
# Requires: torch
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2022 NVIDIA Corporation
# Built on Tue_May__3_19:00:59_Pacific_Daylight_Time_2022
# Cuda compilation tools, release 11.7, V11.7.64
# Build cuda_11.7.r11.7/compiler.31294372_0

# %%
#nano version
from ultralytics import YOLO

# Load a model
model = YOLO("yolov8n.yaml")  # build a new model from scratch
model = YOLO("yolov8n.pt")  # load a pretrained model (recommended for training)

# Use the model
model.train(data="coco128.yaml", epochs=10)  # train the model
metrics = model.val()  # evaluate model performance on the validation set
results = model("https://ultralytics.com/images/bus.jpg")  # predict on an image
path = model.export(format="onnx")  # export the model to ONNX format
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    897664  ultralytics.nn.modules.head.Detect           [80, [64, 128, 256]]
# YOLOv8n summary: 225 layers, 3157200 parameters, 3157184 gradients, 8.9 GFLOPs
#
# Ultralytics YOLOv8.1.0 🚀 Python-3.8.18 torch-2.1.2+cu121 CUDA:0 (NVIDIA GeForce GTX 1060 6GB, 6144MiB)
# engine\trainer: task=detect, mode=train, model=yolov8n.pt, data=coco128.yaml, epochs=10, time=None, patience=50, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train3, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs\detect\train3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    897664  ultralytics.nn.modules.head.Detect           [80, [64, 128, 256]]
# Model summary: 225 layers, 3157200 parameters, 3157184 gradients, 8.9 GFLOPs
#
# Transferred 355/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: checks passed ✅
# train: Scanning C:\Users\Dr. Justin\coding\yolov8_sp\datasets\coco128\labels\train2017... 126 images, 2 backgrounds, 0
# train: New cache created: C:\Users\Dr. Justin\coding\yolov8_sp\datasets\coco128\labels\train2017.cache
# val: Scanning C:\Users\Dr. Justin\coding\yolov8_sp\datasets\coco128\labels\train2017.cache... 126 images, 2 backgrounds
# Plotting labels to runs\detect\train3\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000119, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# 10 epochs...
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/10      2.59G      1.208      1.367      1.217        129        640: 100%|██████████| 8/8 [00:03<00:00,  2.04
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:01<0
#                    all        128        929      0.639      0.538      0.614      0.453
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/10      2.56G      1.146      1.417        1.2        110        640: 100%|██████████| 8/8 [00:03<00:00,  2.53
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:01<0
#                    all        128        929      0.677      0.551      0.633      0.466
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/10      2.57G      1.157      1.326      1.206        116        640: 100%|██████████| 8/8 [00:03<00:00,  2.59
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:01<0
#                    all        128        929      0.675      0.566      0.639      0.471
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/10      2.57G      1.154      1.264      1.214         68        640: 100%|██████████| 8/8 [00:03<00:00,  2.61
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:01<0
#                    all        128        929       0.64      0.609      0.653      0.486
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/10      2.58G      1.156      1.295      1.209         96        640: 100%|██████████| 8/8 [00:03<00:00,  2.62
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:01<0
#                    all        128        929      0.672      0.605      0.664      0.494
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/10      2.58G      1.141      1.213      1.203        125        640: 100%|██████████| 8/8 [00:03<00:00,  2.61
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:01<0
#                    all        128        929      0.696      0.617      0.683      0.505
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/10      2.57G      1.129      1.195      1.187         76        640: 100%|██████████| 8/8 [00:03<00:00,  2.64
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:01<0
#                    all        128        929      0.702      0.627      0.692      0.512
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/10      2.57G      1.105      1.163       1.17        141        640: 100%|██████████| 8/8 [00:03<00:00,  2.54
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:01<0
#                    all        128        929      0.699      0.635      0.697      0.515
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/10      2.61G       1.08      1.134      1.178        106        640: 100%|██████████| 8/8 [00:03<00:00,  2.55
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:01<0
#                    all        128        929      0.711      0.627      0.699      0.516
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/10      2.57G      1.126      1.181      1.183        171        640: 100%|██████████| 8/8 [00:03<00:00,  2.53
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:01<0
#                    all        128        929      0.708      0.626      0.699      0.517
# 10 epochs completed in 0.025 hours.
# Optimizer stripped from runs\detect\train3\weights\last.pt, 6.5MB
# Optimizer stripped from runs\detect\train3\weights\best.pt, 6.5MB
#
# Validating runs\detect\train3\weights\best.pt...
# Ultralytics YOLOv8.1.0 🚀 Python-3.8.18 torch-2.1.2+cu121 CUDA:0 (NVIDIA GeForce GTX 1060 6GB, 6144MiB)
# Model summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:01<0
#                    all        128        929       0.71      0.625      0.699      0.517
#                 person        128        254      0.858      0.668      0.782      0.565
#                bicycle        128          6          1      0.327      0.373      0.326
#                    car        128         46      0.696      0.217       0.31      0.189
#             motorcycle        128          5       0.68        0.8      0.938      0.742
#               airplane        128          6      0.825          1      0.972      0.798
#                    bus        128          7      0.814      0.714      0.699      0.626
#                  train        128          3      0.598          1      0.863      0.728
#                  truck        128         12      0.865        0.5      0.544      0.371
#                   boat        128          6        0.5      0.333      0.602      0.359
#          traffic light        128         14      0.735      0.202      0.202      0.146
#              stop sign        128          2      0.744          1      0.995      0.661
#                  bench        128          9      0.794      0.432      0.635      0.474
#                   bird        128         16      0.913      0.875      0.957      0.662
#                    cat        128          4      0.898          1      0.995      0.865
#                    dog        128          9      0.659      0.889       0.94      0.742
#                  horse        128          2      0.657          1      0.995      0.547
#               elephant        128         17      0.852      0.882      0.953      0.749
#                   bear        128          1      0.484          1      0.995      0.995
#                  zebra        128          4      0.871          1      0.995      0.972
#                giraffe        128          9       0.87          1      0.984      0.806
#               backpack        128          6      0.614      0.281      0.389      0.275
#               umbrella        128         18      0.605      0.611      0.688       0.48
#                handbag        128         19          1      0.095      0.322      0.165
#                    tie        128          7      0.759      0.714      0.705       0.48
#               suitcase        128          4      0.751          1      0.895      0.612
#                frisbee        128          5      0.579        0.8      0.732      0.632
#                   skis        128          1      0.895          1      0.995      0.497
#              snowboard        128          7      0.643      0.714      0.804      0.555
#            sports ball        128          6      0.733        0.5      0.572      0.302
#                   kite        128         10      0.795       0.39      0.572      0.208
#           baseball bat        128          4      0.822        0.5      0.509      0.265
#         baseball glove        128          7      0.873      0.429      0.431      0.288
#             skateboard        128          5      0.577        0.6      0.613      0.433
#          tennis racket        128          7      0.503       0.29      0.568       0.32
#                 bottle        128         18       0.51       0.29      0.371      0.244
#             wine glass        128         16      0.605      0.576      0.664      0.371
#                    cup        128         36      0.707      0.278       0.44      0.308
#                   fork        128          6      0.631      0.167      0.293      0.233
#                  knife        128         16      0.718        0.5      0.625      0.373
#                  spoon        128         22      0.472      0.325      0.395      0.231
#                   bowl        128         28       0.67      0.714      0.729       0.59
#                 banana        128          1       0.08       0.24      0.332     0.0733
#               sandwich        128          2      0.795          1      0.995      0.995
#                 orange        128          4      0.726      0.678      0.895      0.593
#               broccoli        128         11      0.574      0.273      0.336      0.262
#                 carrot        128         24      0.723      0.667      0.788      0.487
#                hot dog        128          2      0.558          1      0.828      0.795
#                  pizza        128          5      0.838        0.8      0.962      0.814
#                  donut        128         14      0.524          1      0.923      0.831
#                   cake        128          4       0.83          1      0.995      0.904
#                  chair        128         35      0.589      0.486      0.588      0.349
#                  couch        128          6      0.596      0.667      0.755       0.57
#           potted plant        128         14       0.78      0.762      0.779      0.532
#                    bed        128          3      0.751      0.667      0.806      0.679
#           dining table        128         13      0.489      0.538      0.555      0.456
#                 toilet        128          2      0.953          1      0.995      0.946
#                     tv        128          2      0.888          1      0.995      0.846
#                 laptop        128          3      0.844      0.667       0.83      0.749
#                  mouse        128          2          1          0     0.0599    0.00599
#                 remote        128          8      0.853        0.5      0.634      0.501
#             cell phone        128          8        0.4      0.125      0.175      0.105
#              microwave        128          3      0.717      0.667      0.863      0.773
#                   oven        128          5      0.517        0.4        0.5      0.369
#                   sink        128          6      0.457      0.167      0.322      0.216
#           refrigerator        128          5      0.753        0.8      0.846      0.696
#                   book        128         29      0.657      0.199       0.45       0.23
#                  clock        128          9      0.888      0.882      0.903      0.768
#                   vase        128          2      0.465          1      0.828      0.795
#               scissors        128          1          1          0      0.995      0.149
#             teddy bear        128         21      0.672      0.571      0.717      0.477
#             toothbrush        128          5      0.681          1      0.928      0.535
# Speed: 0.4ms preprocess, 4.8ms inference, 0.0ms loss, 1.2ms postprocess per image
# Results saved to runs\detect\train3
# Ultralytics YOLOv8.1.0 🚀 Python-3.8.18 torch-2.1.2+cu121 CUDA:0 (NVIDIA GeForce GTX 1060 6GB, 6144MiB)
# Model summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
# val: Scanning C:\Users\Dr. Justin\coding\yolov8_sp\datasets\coco128\labels\train2017.cache... 126 images, 2 backgrounds
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:01<0
#                    all        128        929      0.706      0.613      0.696      0.519
#                 person        128        254       0.85      0.668      0.783      0.567
#                bicycle        128          6          1      0.327       0.37      0.307
#                    car        128         46      0.697      0.217      0.321      0.192
#             motorcycle        128          5      0.681      0.862      0.938      0.742
#               airplane        128          6      0.824          1      0.972      0.798
#                    bus        128          7      0.819      0.714      0.722      0.666
#                  train        128          3      0.598          1      0.913      0.772
#                  truck        128         12      0.866        0.5      0.545      0.364
#                   boat        128          6      0.604      0.333      0.482      0.309
#          traffic light        128         14      0.565      0.143       0.18      0.137
#              stop sign        128          2      0.744          1      0.995      0.659
#                  bench        128          9      0.793      0.429      0.635      0.474
#                   bird        128         16      0.914      0.875      0.956      0.658
#                    cat        128          4      0.901          1      0.995      0.886
#                    dog        128          9      0.662      0.889       0.94      0.747
#                  horse        128          2      0.659          1      0.995      0.547
#               elephant        128         17      0.843      0.882      0.953      0.753
#                   bear        128          1      0.485          1      0.995      0.995
#                  zebra        128          4      0.869          1      0.995      0.972
#                giraffe        128          9      0.737          1      0.926      0.767
#               backpack        128          6       0.61      0.277      0.389      0.259
#               umbrella        128         18      0.605      0.611      0.688      0.481
#                handbag        128         19          1     0.0947      0.315      0.163
#                    tie        128          7       0.76      0.714      0.705      0.493
#               suitcase        128          4      0.748          1      0.895      0.612
#                frisbee        128          5      0.581        0.8      0.732      0.632
#                   skis        128          1      0.896          1      0.995      0.497
#              snowboard        128          7      0.643      0.714      0.814      0.567
#            sports ball        128          6      0.727        0.5      0.596      0.334
#                   kite        128         10      0.795       0.39      0.604      0.202
#           baseball bat        128          4      0.632       0.25      0.426       0.25
#         baseball glove        128          7       0.86      0.429      0.431      0.303
#             skateboard        128          5      0.787        0.6      0.609      0.461
#          tennis racket        128          7        0.5      0.286      0.568      0.329
#                 bottle        128         18      0.533      0.278      0.416      0.269
#             wine glass        128         16      0.632      0.438      0.628      0.365
#                    cup        128         36      0.596      0.287      0.459      0.321
#                   fork        128          6       0.61      0.167      0.233      0.208
#                  knife        128         16      0.663        0.5      0.609      0.364
#                  spoon        128         22      0.525      0.318      0.399      0.229
#                   bowl        128         28      0.638       0.75      0.738      0.592
#                 banana        128          1          0          0      0.199     0.0486
#               sandwich        128          2      0.886          1      0.995      0.995
#                 orange        128          4      0.723       0.67      0.895      0.594
#               broccoli        128         11      0.549      0.273       0.33      0.245
#                 carrot        128         24       0.67      0.678      0.782      0.478
#                hot dog        128          2      0.548          1      0.828      0.795
#                  pizza        128          5      0.898          1      0.995       0.85
#                  donut        128         14      0.525          1      0.923      0.828
#                   cake        128          4      0.773          1      0.995      0.904
#                  chair        128         35      0.592      0.486      0.587      0.348
#                  couch        128          6      0.702      0.667      0.797      0.592
#           potted plant        128         14      0.731      0.714      0.777      0.531
#                    bed        128          3      0.751      0.667      0.913      0.764
#           dining table        128         13      0.549      0.538      0.603      0.486
#                 toilet        128          2      0.955          1      0.995      0.946
#                     tv        128          2       0.88          1      0.995      0.846
#                 laptop        128          3      0.845      0.667      0.747      0.699
#                  mouse        128          2          1          0     0.0602    0.00602
#                 remote        128          8      0.854        0.5      0.639      0.504
#             cell phone        128          8      0.404      0.125       0.17      0.102
#              microwave        128          3      0.716      0.667      0.863      0.756
#                   oven        128          5      0.517        0.4       0.52      0.383
#                   sink        128          6      0.459      0.167      0.344       0.23
#           refrigerator        128          5      0.766      0.666      0.832      0.679
#                   book        128         29      0.603      0.138      0.446       0.23
#                  clock        128          9      0.888      0.881      0.903      0.754
#                   vase        128          2      0.465          1      0.828      0.795
#               scissors        128          1          1          0      0.995      0.149
#             teddy bear        128         21      0.672      0.571      0.707      0.477
#             toothbrush        128          5       0.75        0.8      0.898      0.566
# Speed: 0.7ms preprocess, 6.5ms inference, 0.0ms loss, 2.4ms postprocess per image
# Results saved to runs\detect\train32
#
# Downloading https://ultralytics.com/images/bus.jpg to 'bus.jpg'...
# 100%|███████████████████████████████████████████████████████████████████████████████| 476k/476k [00:00<00:00, 30.0MB/s]
# image 1/1 C:\Users\Dr. Justin\coding\yolov8_sp\bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 83.7ms
# Speed: 1.6ms preprocess, 83.7ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# Ultralytics YOLOv8.1.0 🚀 Python-3.8.18 torch-2.1.2+cu121 CPU (Intel Core(TM) i5-8500 3.00GHz)
#
# PyTorch: starting from 'runs\detect\train3\weights\best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 84, 8400) (6.2 MB)
# requirements: Ultralytics requirement ['onnx>=1.12.0'] not found, attempting AutoUpdate...
# Collecting onnx>=1.12.0
#   Downloading onnx-1.15.0-cp38-cp38-win_amd64.whl.metadata (15 kB)
# Requirement already satisfied: numpy in c:\users\dr. justin\anaconda3\envs\yolov8\lib\site-packages (from onnx>=1.12.0) (1.24.4)
# Collecting protobuf>=3.20.2 (from onnx>=1.12.0)
#   Downloading protobuf-4.25.2-cp38-cp38-win_amd64.whl.metadata (541 bytes)
# Downloading onnx-1.15.0-cp38-cp38-win_amd64.whl (14.3 MB)
#    ---------------------------------------- 14.3/14.3 MB 32.8 MB/s eta 0:00:00
# Downloading protobuf-4.25.2-cp38-cp38-win_amd64.whl (413 kB)
#    ---------------------------------------- 413.4/413.4 kB ? eta 0:00:00
# Installing collected packages: protobuf, onnx
# Successfully installed onnx-1.15.0 protobuf-4.25.2
#
# requirements: AutoUpdate success ✅ 23.8s, installed 1 package: ['onnx>=1.12.0']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.15.0 opset 17...
# ONNX: export success ✅ 25.3s, saved as 'runs\detect\train3\weights\best.onnx' (12.2 MB)
#
# Export complete (27.2s)
# Results saved to C:\Users\Dr. Justin\coding\yolov8_sp\runs\detect\train3\weights
# Predict:         yolo predict task=detect model=runs\detect\train3\weights\best.onnx imgsz=640
# Validate:        yolo val task=detect model=runs\detect\train3\weights\best.onnx imgsz=640 data=C:\Users\Dr. Justin\anaconda3\envs\yolov8\Lib\site-packages\ultralytics\cfg\datasets\coco128.yaml
# Visualize:       https://netron.app

# %%
# medium version
from ultralytics import YOLO

# Load a model
model = YOLO("yolov8m.yaml")  # build a new model from scratch
model = YOLO("yolov8m.pt")  # load a pretrained model (recommended for training)

# Use the model
model.train(data="coco128.yaml", epochs=10)  # train the model
metrics = model.val()  # evaluate model performance on the validation set
results = model("https://ultralytics.com/images/bus.jpg")  # predict on an image
path = model.export(format="onnx")  # export the model to ONNX format
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1      1392  ultralytics.nn.modules.conv.Conv             [3, 48, 3, 2]
#   1                  -1  1     41664  ultralytics.nn.modules.conv.Conv             [48, 96, 3, 2]
#   2                  -1  2    111360  ultralytics.nn.modules.block.C2f             [96, 96, 2, True]
#   3                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   4                  -1  4    813312  ultralytics.nn.modules.block.C2f             [192, 192, 4, True]
#   5                  -1  1    664320  ultralytics.nn.modules.conv.Conv             [192, 384, 3, 2]
#   6                  -1  4   3248640  ultralytics.nn.modules.block.C2f             [384, 384, 4, True]
#   7                  -1  1   1991808  ultralytics.nn.modules.conv.Conv             [384, 576, 3, 2]
#   8                  -1  2   3985920  ultralytics.nn.modules.block.C2f             [576, 576, 2, True]
#   9                  -1  1    831168  ultralytics.nn.modules.block.SPPF            [576, 576, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  2   1993728  ultralytics.nn.modules.block.C2f             [960, 384, 2]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  2    517632  ultralytics.nn.modules.block.C2f             [576, 192, 2]
#  16                  -1  1    332160  ultralytics.nn.modules.conv.Conv             [192, 192, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  2   1846272  ultralytics.nn.modules.block.C2f             [576, 384, 2]
#  19                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  2   4207104  ultralytics.nn.modules.block.C2f             [960, 576, 2]
#  22        [15, 18, 21]  1   3822016  ultralytics.nn.modules.head.Detect           [80, [192, 384, 576]]
# YOLOv8m summary: 295 layers, 25902640 parameters, 25902624 gradients, 79.3 GFLOPs
#
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8m.pt to 'yolov8m.pt'...
#   0%|          | 0.00/49.7M [00:00<?, ?B/s]
# Ultralytics YOLOv8.0.235 🚀 Python-3.8.18 torch-1.13.0+cu117 CUDA:0 (NVIDIA GeForce RTX 2070 with Max-Q Design, 8192MiB)
# WARNING ⚠️ Upgrade to torch>=2.0.0 for deterministic training.
# engine\trainer: task=detect, mode=train, model=yolov8m.pt, data=coco128.yaml, epochs=10, time=None, patience=50, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train16, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs\detect\train16
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1392  ultralytics.nn.modules.conv.Conv             [3, 48, 3, 2]
#   1                  -1  1     41664  ultralytics.nn.modules.conv.Conv             [48, 96, 3, 2]
#   2                  -1  2    111360  ultralytics.nn.modules.block.C2f             [96, 96, 2, True]
#   3                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   4                  -1  4    813312  ultralytics.nn.modules.block.C2f             [192, 192, 4, True]
#   5                  -1  1    664320  ultralytics.nn.modules.conv.Conv             [192, 384, 3, 2]
#   6                  -1  4   3248640  ultralytics.nn.modules.block.C2f             [384, 384, 4, True]
#   7                  -1  1   1991808  ultralytics.nn.modules.conv.Conv             [384, 576, 3, 2]
#   8                  -1  2   3985920  ultralytics.nn.modules.block.C2f             [576, 576, 2, True]
#   9                  -1  1    831168  ultralytics.nn.modules.block.SPPF            [576, 576, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  2   1993728  ultralytics.nn.modules.block.C2f             [960, 384, 2]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  2    517632  ultralytics.nn.modules.block.C2f             [576, 192, 2]
#  16                  -1  1    332160  ultralytics.nn.modules.conv.Conv             [192, 192, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  2   1846272  ultralytics.nn.modules.block.C2f             [576, 384, 2]
#  19                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  2   4207104  ultralytics.nn.modules.block.C2f             [960, 576, 2]
#  22        [15, 18, 21]  1   3822016  ultralytics.nn.modules.head.Detect           [80, [192, 384, 576]]
# Model summary: 295 layers, 25902640 parameters, 25902624 gradients, 79.3 GFLOPs
#
# Transferred 475/475 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: checks passed ✅
# train: Scanning C:\Users\Sunpil Kim\Coding files\Python\yolov8\datasets\coco128\labels\train2017.cache... 126 images, 2
# val: Scanning C:\Users\Sunpil Kim\Coding files\Python\yolov8\datasets\coco128\labels\train2017.cache... 126 images, 2 b
# Plotting labels to runs\detect\train16\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000119, momentum=0.9) with parameter groups 77 weight(decay=0.0), 84 weight(decay=0.0005), 83 bias(decay=0.0)
# 10 epochs...
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/10      6.76G     0.9201     0.8987      1.107        122        640: 100%|██████████| 8/8 [00:04<00:00,  1.65
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:01<0
#                    all        128        929      0.736      0.736      0.789      0.612
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/10      7.03G     0.9167     0.8228      1.096        112        640: 100%|██████████| 8/8 [00:03<00:00,  2.05
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:01<0
#                    all        128        929       0.76      0.759      0.805      0.635
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/10      6.98G     0.8879      0.761      1.072        116        640: 100%|██████████| 8/8 [00:03<00:00,  2.15
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:02<0
#                    all        128        929      0.801      0.754      0.819       0.65
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/10         7G     0.8712     0.7151      1.069         68        640: 100%|██████████| 8/8 [00:03<00:00,  2.06
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:01<0
#                    all        128        929      0.825      0.768      0.833      0.663
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/10      6.96G     0.8679     0.6883      1.058         96        640: 100%|██████████| 8/8 [00:03<00:00,  2.09
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:02<0
#                    all        128        929      0.844      0.773       0.86      0.685
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/10      6.94G      0.864     0.6514      1.065        120        640: 100%|██████████| 8/8 [00:03<00:00,  2.13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:01<0
#                    all        128        929      0.794      0.824      0.869      0.698
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/10      6.97G     0.8088     0.6003      1.015         69        640: 100%|██████████| 8/8 [00:03<00:00,  2.07
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:02<0
#                    all        128        929      0.881      0.779      0.874      0.705
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/10      6.93G     0.8196     0.6225      1.037        141        640: 100%|██████████| 8/8 [00:03<00:00,  2.09
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:02<0
#                    all        128        929      0.869      0.801      0.877       0.71
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/10      6.93G     0.7933     0.5862       1.02        104        640: 100%|██████████| 8/8 [00:03<00:00,  2.14
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:01<0
#                    all        128        929      0.874      0.809      0.883      0.716
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/10      6.97G     0.8019     0.5677      1.015        170        640: 100%|██████████| 8/8 [00:03<00:00,  2.14
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:01<0
#                    all        128        929      0.877      0.809      0.883      0.718
# 10 epochs completed in 0.027 hours.
# Optimizer stripped from runs\detect\train16\weights\last.pt, 52.1MB
# Optimizer stripped from runs\detect\train16\weights\best.pt, 52.1MB
#
# Validating runs\detect\train16\weights\best.pt...
# Ultralytics YOLOv8.0.235 🚀 Python-3.8.18 torch-1.13.0+cu117 CUDA:0 (NVIDIA GeForce RTX 2070 with Max-Q Design, 8192MiB)
# Model summary (fused): 218 layers, 25886080 parameters, 0 gradients, 78.9 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:02<0
#                    all        128        929      0.877      0.809      0.884      0.718
#                 person        128        254      0.964      0.742       0.89      0.696
#                bicycle        128          6          1      0.428      0.809      0.637
#                    car        128         46      0.948      0.397       0.61      0.341
#             motorcycle        128          5       0.91          1      0.995       0.86
#               airplane        128          6      0.931          1      0.995      0.931
#                    bus        128          7          1      0.856      0.995      0.873
#                  train        128          3      0.772          1      0.995      0.963
#                  truck        128         12      0.982        0.5      0.734      0.492
#                   boat        128          6      0.819        0.5       0.78      0.548
#          traffic light        128         14      0.843      0.357      0.559      0.325
#              stop sign        128          2      0.832          1      0.995      0.895
#                  bench        128          9          1      0.752      0.995      0.838
#                   bird        128         16          1      0.969      0.995      0.745
#                    cat        128          4      0.903          1      0.995      0.918
#                    dog        128          9      0.939          1      0.995      0.916
#                  horse        128          2      0.851          1      0.995      0.799
#               elephant        128         17          1      0.918      0.947      0.853
#                   bear        128          1      0.764          1      0.995      0.895
#                  zebra        128          4      0.905          1      0.995      0.995
#                giraffe        128          9      0.976          1      0.995      0.887
#               backpack        128          6      0.749      0.833      0.837      0.693
#               umbrella        128         18      0.771          1      0.968      0.768
#                handbag        128         19          1      0.522      0.674      0.503
#                    tie        128          7          1       0.85       0.86      0.731
#               suitcase        128          4       0.94          1      0.995      0.673
#                frisbee        128          5      0.872        0.8      0.807      0.741
#                   skis        128          1      0.836          1      0.995      0.895
#              snowboard        128          7      0.968          1      0.995       0.83
#            sports ball        128          6          1      0.576      0.741      0.425
#                   kite        128         10       0.88        0.3      0.569      0.228
#           baseball bat        128          4      0.717       0.75      0.624      0.541
#         baseball glove        128          7          1      0.357       0.44      0.266
#             skateboard        128          5      0.982          1      0.995      0.639
#          tennis racket        128          7          1      0.655      0.721      0.469
#                 bottle        128         18       0.92      0.638      0.875      0.633
#             wine glass        128         16      0.694      0.438      0.842      0.565
#                    cup        128         36      0.912      0.865      0.957      0.663
#                   fork        128          6          1      0.758      0.846      0.572
#                  knife        128         16      0.892       0.75       0.87      0.635
#                  spoon        128         22       0.88      0.773      0.795      0.631
#                   bowl        128         28      0.845      0.786      0.877      0.733
#                 banana        128          1       0.73          1      0.995      0.995
#               sandwich        128          2      0.675          1      0.995      0.995
#                 orange        128          4      0.709          1      0.995      0.805
#               broccoli        128         11          1      0.419      0.605      0.443
#                 carrot        128         24      0.899      0.917      0.921      0.703
#                hot dog        128          2      0.823          1      0.995      0.995
#                  pizza        128          5      0.912          1      0.995      0.918
#                  donut        128         14      0.776          1       0.99      0.924
#                   cake        128          4      0.884          1      0.995      0.905
#                  chair        128         35        0.9      0.514      0.835      0.591
#                  couch        128          6      0.985          1      0.995      0.879
#           potted plant        128         14      0.926       0.89      0.973      0.782
#                    bed        128          3      0.864          1      0.995      0.963
#           dining table        128         13      0.836      0.783      0.901      0.711
#                 toilet        128          2      0.852          1      0.995      0.946
#                     tv        128          2      0.843          1      0.995      0.947
#                 laptop        128          3      0.677      0.667       0.83      0.765
#                  mouse        128          2      0.758        0.5      0.745      0.526
#                 remote        128          8          1      0.684      0.783      0.678
#             cell phone        128          8      0.887      0.625      0.709      0.432
#              microwave        128          3        0.8          1      0.995       0.93
#                   oven        128          5      0.724        0.6      0.648      0.524
#                   sink        128          6       0.58      0.694      0.746      0.528
#           refrigerator        128          5      0.864          1      0.995      0.817
#                   book        128         29      0.769      0.344      0.649      0.383
#                  clock        128          9      0.914      0.889      0.968      0.846
#                   vase        128          2       0.96          1      0.995      0.921
#               scissors        128          1       0.67          1      0.995      0.298
#             teddy bear        128         21      0.945      0.811      0.965      0.751
#             toothbrush        128          5      0.917          1      0.995      0.857
# Speed: 0.8ms preprocess, 8.5ms inference, 0.0ms loss, 2.1ms postprocess per image
# Results saved to runs\detect\train16
# Ultralytics YOLOv8.0.235 🚀 Python-3.8.18 torch-1.13.0+cu117 CUDA:0 (NVIDIA GeForce RTX 2070 with Max-Q Design, 8192MiB)
# Model summary (fused): 218 layers, 25886080 parameters, 0 gradients, 78.9 GFLOPs
# val: Scanning C:\Users\Sunpil Kim\Coding files\Python\yolov8\datasets\coco128\labels\train2017.cache... 126 images, 2 b
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:02<0
#                    all        128        929       0.87      0.816      0.884      0.721
#                 person        128        254       0.96      0.758      0.891      0.697
#                bicycle        128          6          1      0.442      0.809      0.623
#                    car        128         46      0.907      0.423      0.611      0.344
#             motorcycle        128          5      0.913          1      0.995      0.859
#               airplane        128          6      0.926          1      0.995      0.931
#                    bus        128          7          1      0.875      0.995       0.89
#                  train        128          3       0.75          1      0.995      0.963
#                  truck        128         12       0.92        0.5      0.721      0.485
#                   boat        128          6          1       0.63      0.808      0.594
#          traffic light        128         14      0.861      0.443      0.551      0.322
#              stop sign        128          2       0.82          1      0.995      0.895
#                  bench        128          9          1      0.793      0.995      0.856
#                   bird        128         16          1      0.974      0.995      0.753
#                    cat        128          4      0.897          1      0.995      0.918
#                    dog        128          9      0.932          1      0.995      0.926
#                  horse        128          2      0.841          1      0.995      0.799
#               elephant        128         17          1       0.92      0.947      0.853
#                   bear        128          1      0.749          1      0.995      0.895
#                  zebra        128          4      0.899          1      0.995      0.995
#                giraffe        128          9      0.955          1      0.995      0.894
#               backpack        128          6      0.734      0.833      0.837      0.693
#               umbrella        128         18      0.762          1      0.966      0.772
#                handbag        128         19      0.987      0.526      0.668      0.504
#                    tie        128          7      0.992      0.857       0.86      0.731
#               suitcase        128          4      0.941          1      0.995      0.673
#                frisbee        128          5      0.861        0.8      0.807      0.761
#                   skis        128          1      0.811          1      0.995      0.895
#              snowboard        128          7          1      0.994      0.995       0.83
#            sports ball        128          6          1      0.587      0.741      0.425
#                   kite        128         10      0.852        0.3       0.57      0.217
#           baseball bat        128          4       0.72       0.75       0.72      0.559
#         baseball glove        128          7      0.965      0.429       0.44      0.266
#             skateboard        128          5          1      0.951      0.995      0.666
#          tennis racket        128          7          1       0.67      0.721      0.483
#                 bottle        128         18       0.92      0.643      0.875      0.603
#             wine glass        128         16      0.685      0.438      0.842       0.56
#                    cup        128         36      0.905      0.861      0.946      0.652
#                   fork        128          6       0.88      0.667      0.817      0.558
#                  knife        128         16      0.871       0.75      0.876      0.635
#                  spoon        128         22      0.863      0.773      0.794      0.643
#                   bowl        128         28      0.876      0.786      0.879      0.732
#                 banana        128          1      0.714          1      0.995      0.995
#               sandwich        128          2      0.636          1      0.995      0.995
#                 orange        128          4      0.702          1      0.995      0.768
#               broccoli        128         11      0.995      0.455      0.609      0.437
#                 carrot        128         24      0.916       0.91      0.916      0.707
#                hot dog        128          2      0.811          1      0.995      0.995
#                  pizza        128          5      0.935          1      0.995      0.918
#                  donut        128         14      0.752          1       0.99      0.924
#                   cake        128          4      0.877          1      0.995      0.905
#                  chair        128         35      0.904      0.538      0.833      0.588
#                  couch        128          6      0.973          1      0.995      0.879
#           potted plant        128         14      0.926      0.898      0.973      0.777
#                    bed        128          3      0.862          1      0.995      0.941
#           dining table        128         13      0.841      0.816      0.848      0.748
#                 toilet        128          2      0.841          1      0.995      0.946
#                     tv        128          2      0.832          1      0.995      0.946
#                 laptop        128          3      0.631      0.667       0.83      0.765
#                  mouse        128          2      0.736        0.5      0.745      0.527
#                 remote        128          8          1      0.688      0.781      0.674
#             cell phone        128          8      0.867      0.625      0.709      0.447
#              microwave        128          3      0.772          1      0.995       0.93
#                   oven        128          5      0.709        0.6      0.663      0.521
#                   sink        128          6      0.596      0.744       0.78      0.561
#           refrigerator        128          5      0.855          1      0.995      0.827
#                   book        128         29      0.784      0.377      0.649      0.397
#                  clock        128          9      0.906      0.889      0.968      0.856
#                   vase        128          2      0.941          1      0.995      0.921
#               scissors        128          1      0.643          1      0.995      0.298
#             teddy bear        128         21      0.946      0.837      0.937      0.743
#             toothbrush        128          5      0.907          1      0.995      0.895
# Speed: 0.8ms preprocess, 13.2ms inference, 0.0ms loss, 2.6ms postprocess per image
# Results saved to runs\detect\train162
#
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 C:\Users\Sunpil Kim\Coding files\Python\yolov8\bus.jpg: 640x480 4 persons, 1 bicycle, 1 bus, 59.0ms
# Speed: 2.0ms preprocess, 59.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 480)
# Ultralytics YOLOv8.0.235 🚀 Python-3.8.18 torch-1.13.0+cu117 CPU (Intel Core(TM) i7-10875H 2.30GHz)
#
# PyTorch: starting from 'runs\detect\train16\weights\best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 84, 8400) (49.7 MB)
#
# ONNX: starting export with onnx 1.15.0 opset 16...
# ONNX: export success ✅ 2.4s, saved as 'runs\detect\train16\weights\best.onnx' (99.0 MB)
#
# Export complete (5.3s)
# Results saved to C:\Users\Sunpil Kim\Coding files\Python\yolov8\runs\detect\train16\weights
# Predict:         yolo predict task=detect model=runs\detect\train16\weights\best.onnx imgsz=640
# Validate:        yolo val task=detect model=runs\detect\train16\weights\best.onnx imgsz=640 data=C:\envs\yolov8\Lib\site-packages\ultralytics\cfg\datasets\coco128.yaml
# Visualize:       https://netron.app

# %%
# !nvidia-smi
# Out:
# Sat Jan  6 11:23:49 2024
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 516.01       Driver Version: 516.01       CUDA Version: 11.7     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ... WDDM  | 00000000:01:00.0  On |                  N/A |
# | N/A   49C    P8     7W /  N/A |     78MiB /  8192MiB |      3%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
# !taskkill /F /PID 7232

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="DCMVQNAZVaJcGUiWaqad")
project = rf.workspace("spkim").project("avatar-5x2si")
dataset = project.version(1).download("yolov8")
# Out:
# Collecting roboflow
#   Downloading roboflow-1.1.15-py3-none-any.whl.metadata (9.3 kB)
# Collecting certifi==2023.7.22 (from roboflow)
#   Using cached certifi-2023.7.22-py3-none-any.whl.metadata (2.2 kB)
# Collecting chardet==4.0.0 (from roboflow)
#   Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
#      ---------------------------------------- 0.0/178.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/178.7 kB ? eta -:--:--
#      -- ------------------------------------- 10.2/178.7 kB ? eta -:--:--
#      ------------ ------------------------ 61.4/178.7 kB 656.4 kB/s eta 0:00:01
#      -------------------------------------- 178.7/178.7 kB 1.5 MB/s eta 0:00:00
# Collecting cycler==0.10.0 (from roboflow)
#   Downloading cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# Collecting idna==2.10 (from roboflow)
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#      ---------------------------------------- 0.0/58.8 kB ? eta -:--:--
#      ---------------------------------------- 58.8/58.8 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\envs\yolov8\lib\site-packages (from roboflow) (1.4.5)
# Requirement already satisfied: matplotlib in c:\envs\yolov8\lib\site-packages (from roboflow) (3.7.4)
# Requirement already satisfied: numpy>=1.18.5 in c:\envs\yolov8\lib\site-packages (from roboflow) (1.24.4)
# Collecting opencv-python-headless==4.8.0.74 (from roboflow)
#   Downloading opencv_python_headless-4.8.0.74-cp37-abi3-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: Pillow>=7.1.2 in c:\envs\yolov8\lib\site-packages (from roboflow) (10.2.0)
# Collecting pyparsing==2.4.7 (from roboflow)
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#      ---------------------------------------- 0.0/67.8 kB ? eta -:--:--
#      ---------------------------------------- 67.8/67.8 kB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil in c:\envs\yolov8\lib\site-packages (from roboflow) (2.8.2)
# Collecting python-dotenv (from roboflow)
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: requests in c:\envs\yolov8\lib\site-packages (from roboflow) (2.31.0)
# Requirement already satisfied: six in c:\envs\yolov8\lib\site-packages (from roboflow) (1.16.0)
# Collecting supervision (from roboflow)
#   Downloading supervision-0.17.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: urllib3>=1.26.6 in c:\envs\yolov8\lib\site-packages (from roboflow) (2.1.0)
# Requirement already satisfied: tqdm>=4.41.0 in c:\envs\yolov8\lib\site-packages (from roboflow) (4.66.1)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\envs\yolov8\lib\site-packages (from roboflow) (6.0.1)
# Collecting requests-toolbelt (from roboflow)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#      ---------------------------------------- 0.0/54.5 kB ? eta -:--:--
#      ---------------------------------------- 54.5/54.5 kB 2.8 MB/s eta 0:00:00
# Collecting python-magic (from roboflow)
#   Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: colorama in c:\envs\yolov8\lib\site-packages (from tqdm>=4.41.0->roboflow) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\envs\yolov8\lib\site-packages (from matplotlib->roboflow) (1.1.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\envs\yolov8\lib\site-packages (from matplotlib->roboflow) (4.47.0)
# Requirement already satisfied: packaging>=20.0 in c:\envs\yolov8\lib\site-packages (from matplotlib->roboflow) (23.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\envs\yolov8\lib\site-packages (from matplotlib->roboflow) (6.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\envs\yolov8\lib\site-packages (from requests->roboflow) (3.3.2)
# Requirement already satisfied: scipy>=1.9.0 in c:\envs\yolov8\lib\site-packages (from supervision->roboflow) (1.10.1)
# Requirement already satisfied: zipp>=3.1.0 in c:\envs\yolov8\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->roboflow) (3.17.0)
# Downloading roboflow-1.1.15-py3-none-any.whl (69 kB)
#    ---------------------------------------- 0.0/69.9 kB ? eta -:--:--
#    ---------------------------------------- 69.9/69.9 kB 4.0 MB/s eta 0:00:00
# Using cached certifi-2023.7.22-py3-none-any.whl (158 kB)
# Downloading opencv_python_headless-4.8.0.74-cp37-abi3-win_amd64.whl (38.0 MB)
#    ---------------------------------------- 0.0/38.0 MB ? eta -:--:--
#     --------------------------------------- 0.9/38.0 MB 19.8 MB/s eta 0:00:02
#    -- ------------------------------------- 2.1/38.0 MB 22.1 MB/s eta 0:00:02
#    --- ------------------------------------ 3.8/38.0 MB 26.7 MB/s eta 0:00:02
#    ----- ---------------------------------- 5.2/38.0 MB 30.4 MB/s eta 0:00:02
#    ----- ---------------------------------- 5.2/38.0 MB 30.4 MB/s eta 0:00:02
#    ----- ---------------------------------- 5.2/38.0 MB 30.4 MB/s eta 0:00:02
#    ----- ---------------------------------- 5.2/38.0 MB 30.4 MB/s eta 0:00:02
#    ------ --------------------------------- 5.9/38.0 MB 15.0 MB/s eta 0:00:03
#    -------- ------------------------------- 8.3/38.0 MB 18.9 MB/s eta 0:00:02
#    --------- ------------------------------ 9.1/38.0 MB 18.7 MB/s eta 0:00:02
#    ------------ --------------------------- 11.5/38.0 MB 22.6 MB/s eta 0:00:02
#    ------------- -------------------------- 12.5/38.0 MB 21.1 MB/s eta 0:00:02
#    ----------------- ---------------------- 16.2/38.0 MB 43.7 MB/s eta 0:00:01
#    --------------------- ------------------ 19.9/38.0 MB 59.5 MB/s eta 0:00:01
#    ------------------------ --------------- 23.7/38.0 MB 93.0 MB/s eta 0:00:01
#    -------------------------- ------------- 25.2/38.0 MB 81.8 MB/s eta 0:00:01
#    -------------------------- ------------- 25.2/38.0 MB 81.8 MB/s eta 0:00:01
#    -------------------------- ------------- 25.2/38.0 MB 81.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 28.3/38.0 MB 38.5 MB/s eta 0:00:01
#    ---------------------------------- ----- 32.8/38.0 MB 40.9 MB/s eta 0:00:01
#    ---------------------------------------  37.6/38.0 MB 93.9 MB/s eta 0:00:01
#    ---------------------------------------  37.9/38.0 MB 93.9 MB/s eta 0:00:01
#    ---------------------------------------- 38.0/38.0 MB 54.4 MB/s eta 0:00:00
# Downloading supervision-0.17.1-py3-none-any.whl (77 kB)
#    ---------------------------------------- 0.0/77.5 kB ? eta -:--:--
#    ---------------------------------------- 77.5/77.5 kB 4.2 MB/s eta 0:00:00
# Installing collected packages: python-magic, python-dotenv, pyparsing, opencv-python-headless, idna, cycler, chardet, certifi, supervision, requests-toolbelt, roboflow
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
#     Uninstalling pyparsing-3.1.1:
#       Successfully uninstalled pyparsing-3.1.1
#   Attempting uninstall: idna
#     Found existing installation: idna 3.6
#     Uninstalling idna-3.6:
#       Successfully uninstalled idna-3.6
#   Attempting uninstall: cycler
#     Found existing installation: cycler 0.12.1
#     Uninstalling cycler-0.12.1:
#       Successfully uninstalled cycler-0.12.1
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2023.11.17
#     Uninstalling certifi-2023.11.17:
#       Successfully uninstalled certifi-2023.11.17
# Successfully installed certifi-2023.7.22 chardet-4.0.0 cycler-0.10.0 idna-2.10 opencv-python-headless-4.8.0.74 pyparsing-2.4.7 python-dotenv-1.0.0 python-magic-0.4.27 requests-toolbelt-1.0.0 roboflow-1.1.15 supervision-0.17.1
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.0.235, to fix: `pip install ultralytics==8.0.196`
# Downloading Dataset Version Zip in avatar-1 to yolov8:: 100%|█████████████████████████| 37/37 [00:00<00:00, 239.19it/s]
# Extracting Dataset Version Zip to avatar-1 in yolov8:: 100%|████████████████████████████| 8/8 [00:00<00:00, 878.18it/s]

# %%
dataset.location
# Out:
# 'C:\\Users\\Sunpil Kim\\Coding files\\Python\\yolov8\\avatar-1'

# %%
from ultralytics import YOLO
import cv2

model = YOLO("./weights/20240106_best_weight_yolov8_640.pt")
cap = cv2.VideoCapture("./ko_adult_6114.mp4")

while cap.isOpened() :
    ret, frame = cap.read()

    if ret :
        results = model(frame)
        cv2.imshow("Results", results[0].plot())

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cv2.destroyAllWindows()
cap.release()
# Out:
# 0: 640x640 2 fores, 12 hinds, 1 ass, 1 tail, 68.5ms
# Speed: 11.0ms preprocess, 68.5ms inference, 48.0ms postprocess per image at shape (1, 3, 640, 640)
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[3], line 12
#      10 if ret :
#      11     results = model(frame)
# ---> 12     cv2.imshow("Results", results[0].plot())
#      14 if cv2.waitKey(1) & 0xFF == ord('q'):
#      15     break
#
# File C:\envs\yolov8\lib\site-packages\ultralytics\utils\patches.py:55, in imshow(winname, mat)
#      47 def imshow(winname: str, mat: np.ndarray):
#      48     """
#      49     Displays an image in the specified window.
#      50
#    (...)
#      53         mat (np.ndarray): Image to be shown.
#      54     """
# ---> 55     _imshow(winname.encode('unicode_escape').decode(), mat)
#
# error: OpenCV(4.8.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:1272: error: (-2:Unspecified error) The function is not implemented. Rebuild the library with Windows, GTK+ 2.x or Cocoa support. If you are on Ubuntu or Debian, install libgtk2.0-dev and pkg-config, then re-run cmake or configure script in function 'cvShowImage'

# %%
from ultralytics import YOLO
from PIL import Image
import cv2

# Load a model
model = YOLO('./weights/20240106_best_weight_yolov8_640.pt')  # pretrained YOLOv8n model

source = './Hab_01_output.mp4'

# Run batched inference on a list of images
results = model(source, imgsz = 640, class='fore')  # return a list of Results objects

cnt=0
# Show the results
for r in results:
    im_array = r.plot()  # plot a BGR numpy array of predictions
    im = Image.fromarray(im_array[..., ::-1])  # RGB PIL image
    # im.show()  # show image
    im.save(f'frame_{cnt:03}.jpg')  # save image
    cnt+=1

# # Process results list
# for result in results:
#     boxes = result.boxes  # Boxes object for bbox outputs
#     masks = result.masks  # Masks object for segmentation masks outputs
#     keypoints = result.keypoints  # Keypoints object for pose outputs
#     probs = result.probs  # Probs object for classification outputs
#     print(boxes)
# Out:
#   Cell In[16], line 11
#     results = model(source, imgsz = 640, class='fore')  # return a list of Results objects
#                                          ^
# SyntaxError: invalid syntax

# %%
# Bounding box version
import cv2
from ultralytics import YOLO

# Load the YOLOv8 model
model = YOLO('./weights/20240106_best_weight_yolov8_640.pt')

# Open the video file
input_video_name = 'byun_data_1200f.mp4'
output_video_name = 'byun_data_1200f.mp4'
video_path = './'+ input_video_name
cap = cv2.VideoCapture(video_path)

# Define the codec and create VideoWriter object to save the video
fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Codec for .mp4 files
fps = cap.get(cv2.CAP_PROP_FPS)  # Use the same FPS as the source video
frame_width = int(cap.get(3))  # Width of the frames in the video
frame_height = int(cap.get(4))  # Height of the frames in the video
out = cv2.VideoWriter(output_video_name, fourcc, fps, (frame_width, frame_height))

# Loop through the video frames
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        # Run YOLOv8 inference on the frame
        results = model(frame)

        # Visualize the results on the frame
        annotated_frame = results[0].plot(line_width = 1, labels = False)

        # Write the annotated frame to the output video file
        out.write(annotated_frame)

        # Display the annotated frame
        # cv2.imshow("YOLOv8 Inference", annotated_frame)

        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        # Break the loop if the end of the video is reached
        break

# Release everything when done
cap.release()
out.release()  # Release the VideoWriter object
cv2.destroyAllWindows()
# Out:
# 0: 384x640 3 fores, 4 hinds, 5 heads, 4 asss, 2 tails, 5 torsos, 47.0ms
# Speed: 7.0ms preprocess, 47.0ms inference, 9.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fore, 5 hinds, 5 heads, 4 asss, 2 tails, 5 torsos, 36.0ms
# Speed: 6.0ms preprocess, 36.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fore, 5 hinds, 1 nose, 6 heads, 4 asss, 2 tails, 5 torsos, 36.0ms
# Speed: 2.0ms preprocess, 36.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 4 hinds, 2 noses, 4 heads, 4 asss, 2 tails, 5 torsos, 36.0ms
# Speed: 3.0ms preprocess, 36.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 7 hinds, 2 noses, 4 heads, 5 asss, 2 tails, 5 torsos, 36.0ms
# Speed: 3.0ms preprocess, 36.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 7 hinds, 2 noses, 4 heads, 5 asss, 2 tails, 5 torsos, 36.0ms
# Speed: 2.0ms preprocess, 36.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 6 hinds, 3 noses, 4 heads, 3 asss, 3 tails, 5 torsos, 36.0ms
# Speed: 3.0ms preprocess, 36.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 6 hinds, 2 noses, 5 heads, 3 asss, 4 tails, 5 torsos, 36.0ms
# Speed: 4.0ms preprocess, 36.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 7 hinds, 2 noses, 5 heads, 3 asss, 4 tails, 5 torsos, 36.0ms
# Speed: 3.0ms preprocess, 36.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 7 hinds, 2 noses, 5 heads, 3 asss, 3 tails, 5 torsos, 36.0ms
# Speed: 2.0ms preprocess, 36.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 fores, 10 hinds, 3 noses, 6 heads, 4 asss, 2 tails, 5 torsos, 35.0ms
# Speed: 3.0ms preprocess, 35.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 fores, 9 hinds, 3 noses, 5 heads, 4 asss, 2 tails, 5 torsos, 72.0ms
# Speed: 8.9ms preprocess, 72.0ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 4 hinds, 2 noses, 4 heads, 6 asss, 3 tails, 5 torsos, 74.0ms
# Speed: 3.0ms preprocess, 74.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fores, 4 hinds, 3 noses, 4 heads, 5 asss, 3 tails, 5 torsos, 75.0ms
# Speed: 3.0ms preprocess, 75.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 5 hinds, 4 noses, 5 heads, 5 asss, 2 tails, 6 torsos, 75.0ms
# Speed: 5.0ms preprocess, 75.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 5 hinds, 4 noses, 5 heads, 5 asss, 2 tails, 5 torsos, 74.0ms
# Speed: 4.0ms preprocess, 74.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 8 hinds, 4 noses, 6 heads, 5 asss, 2 tails, 5 torsos, 75.0ms
# Speed: 3.0ms preprocess, 75.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 6 hinds, 4 noses, 4 heads, 5 asss, 3 tails, 5 torsos, 75.0ms
# Speed: 4.0ms preprocess, 75.0ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 5 hinds, 3 noses, 4 heads, 6 asss, 4 tails, 5 torsos, 75.0ms
# Speed: 4.0ms preprocess, 75.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 4 hinds, 2 noses, 5 heads, 4 asss, 3 tails, 5 torsos, 75.0ms
# Speed: 4.0ms preprocess, 75.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 3 hinds, 1 nose, 4 heads, 5 asss, 2 tails, 5 torsos, 76.0ms
# Speed: 4.0ms preprocess, 76.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 4 hinds, 1 nose, 4 heads, 5 asss, 2 tails, 5 torsos, 77.0ms
# Speed: 4.0ms preprocess, 77.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 5 hinds, 3 noses, 5 heads, 5 asss, 5 tails, 5 torsos, 77.0ms
# Speed: 3.0ms preprocess, 77.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 4 hinds, 3 noses, 4 heads, 4 asss, 4 tails, 5 torsos, 76.0ms
# Speed: 3.0ms preprocess, 76.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 6 hinds, 1 nose, 4 heads, 4 asss, 3 tails, 5 torsos, 76.0ms
# Speed: 4.0ms preprocess, 76.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 4 hinds, 1 nose, 4 heads, 3 asss, 5 tails, 5 torsos, 77.0ms
# Speed: 3.0ms preprocess, 77.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 4 hinds, 3 noses, 5 heads, 5 asss, 4 tails, 5 torsos, 77.0ms
# Speed: 4.0ms preprocess, 77.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 3 hinds, 4 heads, 3 asss, 5 tails, 5 torsos, 77.0ms
# Speed: 4.0ms preprocess, 77.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 4 hinds, 5 heads, 3 asss, 2 tails, 5 torsos, 79.0ms
# Speed: 8.0ms preprocess, 79.0ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 4 hinds, 5 heads, 3 asss, 4 tails, 5 torsos, 81.0ms
# Speed: 7.0ms preprocess, 81.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fores, 4 hinds, 3 heads, 3 asss, 4 tails, 5 torsos, 80.0ms
# Speed: 4.0ms preprocess, 80.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 3 hinds, 1 nose, 4 heads, 3 asss, 3 tails, 5 torsos, 79.0ms
# Speed: 3.0ms preprocess, 79.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 3 hinds, 1 nose, 4 heads, 3 asss, 4 tails, 5 torsos, 79.0ms
# Speed: 4.0ms preprocess, 79.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 fores, 4 hinds, 2 noses, 4 heads, 4 asss, 4 tails, 5 torsos, 79.0ms
# Speed: 4.0ms preprocess, 79.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 5 hinds, 2 noses, 4 heads, 3 asss, 3 tails, 5 torsos, 79.0ms
# Speed: 4.0ms preprocess, 79.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 6 hinds, 2 noses, 4 heads, 4 asss, 3 tails, 5 torsos, 79.0ms
# Speed: 4.0ms preprocess, 79.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 7 hinds, 4 noses, 5 heads, 3 asss, 3 tails, 5 torsos, 79.0ms
# Speed: 3.0ms preprocess, 79.0ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 fores, 6 hinds, 3 noses, 6 heads, 5 asss, 3 tails, 5 torsos, 79.8ms
# Speed: 5.0ms preprocess, 79.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 5 hinds, 2 noses, 4 heads, 6 asss, 3 tails, 5 torsos, 78.0ms
# Speed: 4.0ms preprocess, 78.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 6 hinds, 4 noses, 4 heads, 6 asss, 3 tails, 5 torsos, 80.0ms
# Speed: 3.0ms preprocess, 80.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 6 hinds, 3 noses, 4 heads, 5 asss, 3 tails, 5 torsos, 80.0ms
# Speed: 3.0ms preprocess, 80.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 6 hinds, 3 noses, 5 heads, 5 asss, 2 tails, 5 torsos, 80.0ms
# Speed: 4.0ms preprocess, 80.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 7 hinds, 3 noses, 5 heads, 6 asss, 4 tails, 5 torsos, 81.0ms
# Speed: 4.0ms preprocess, 81.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 5 hinds, 3 noses, 4 heads, 4 asss, 4 tails, 5 torsos, 81.0ms
# Speed: 4.0ms preprocess, 81.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 6 hinds, 3 noses, 4 heads, 4 asss, 4 tails, 6 torsos, 82.0ms
# Speed: 5.0ms preprocess, 82.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 5 hinds, 3 noses, 4 heads, 4 asss, 3 tails, 5 torsos, 81.0ms
# Speed: 3.0ms preprocess, 81.0ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 6 hinds, 3 noses, 6 heads, 3 asss, 5 tails, 5 torsos, 80.0ms
# Speed: 4.0ms preprocess, 80.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 fores, 5 hinds, 4 noses, 4 heads, 4 asss, 6 tails, 5 torsos, 79.0ms
# Speed: 3.0ms preprocess, 79.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 fores, 6 hinds, 5 noses, 5 heads, 4 asss, 5 tails, 5 torsos, 80.0ms
# Speed: 3.0ms preprocess, 80.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 6 hinds, 3 noses, 4 heads, 4 asss, 5 tails, 5 torsos, 80.0ms
# Speed: 3.0ms preprocess, 80.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 6 hinds, 3 noses, 4 heads, 2 asss, 2 tails, 5 torsos, 80.0ms
# Speed: 3.0ms preprocess, 80.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 4 hinds, 3 noses, 6 heads, 4 asss, 3 tails, 5 torsos, 79.0ms
# Speed: 4.0ms preprocess, 79.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 3 hinds, 3 noses, 5 heads, 4 asss, 3 tails, 5 torsos, 80.0ms
# Speed: 4.0ms preprocess, 80.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fores, 3 hinds, 4 noses, 4 heads, 5 asss, 2 tails, 5 torsos, 80.0ms
# Speed: 3.0ms preprocess, 80.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fores, 3 hinds, 3 noses, 4 heads, 5 asss, 3 tails, 5 torsos, 80.0ms
# Speed: 8.0ms preprocess, 80.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fores, 3 hinds, 3 noses, 4 heads, 4 asss, 2 tails, 5 torsos, 77.0ms
# Speed: 4.0ms preprocess, 77.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 3 hinds, 3 noses, 4 heads, 4 asss, 3 tails, 5 torsos, 76.0ms
# Speed: 4.0ms preprocess, 76.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 3 hinds, 4 noses, 5 heads, 4 asss, 2 tails, 5 torsos, 76.0ms
# Speed: 4.0ms preprocess, 76.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 3 hinds, 2 noses, 4 heads, 3 asss, 2 tails, 5 torsos, 76.0ms
# Speed: 4.0ms preprocess, 76.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 2 hinds, 4 noses, 5 heads, 3 asss, 3 tails, 5 torsos, 76.0ms
# Speed: 3.0ms preprocess, 76.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 3 hinds, 2 noses, 6 heads, 3 asss, 3 tails, 5 torsos, 75.0ms
# Speed: 4.0ms preprocess, 75.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 3 hinds, 1 nose, 5 heads, 3 asss, 3 tails, 5 torsos, 76.8ms
# Speed: 5.2ms preprocess, 76.8ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 4 hinds, 3 noses, 5 heads, 3 asss, 2 tails, 5 torsos, 77.0ms
# Speed: 5.0ms preprocess, 77.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 6 hinds, 3 noses, 5 heads, 3 asss, 3 tails, 5 torsos, 78.0ms
# Speed: 8.7ms preprocess, 78.0ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 5 hinds, 1 nose, 4 heads, 4 asss, 3 tails, 5 torsos, 78.0ms
# Speed: 5.0ms preprocess, 78.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 fores, 5 hinds, 1 nose, 4 heads, 3 asss, 3 tails, 5 torsos, 78.0ms
# Speed: 3.0ms preprocess, 78.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 5 hinds, 1 nose, 4 heads, 4 asss, 2 tails, 5 torsos, 78.0ms
# Speed: 7.0ms preprocess, 78.0ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 5 hinds, 1 nose, 5 heads, 5 asss, 2 tails, 5 torsos, 79.0ms
# Speed: 3.0ms preprocess, 79.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 5 hinds, 1 nose, 5 heads, 5 asss, 2 tails, 5 torsos, 81.0ms
# Speed: 4.0ms preprocess, 81.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 4 hinds, 2 noses, 6 heads, 4 asss, 2 tails, 5 torsos, 81.0ms
# Speed: 4.0ms preprocess, 81.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 4 hinds, 1 nose, 4 heads, 4 asss, 2 tails, 5 torsos, 80.0ms
# Speed: 5.0ms preprocess, 80.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fores, 4 hinds, 2 noses, 4 heads, 3 asss, 2 tails, 5 torsos, 80.0ms
# Speed: 3.0ms preprocess, 80.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fores, 3 hinds, 1 nose, 5 heads, 4 asss, 2 tails, 5 torsos, 79.0ms
# Speed: 4.0ms preprocess, 79.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 2 hinds, 2 noses, 4 heads, 4 asss, 2 tails, 5 torsos, 80.0ms
# Speed: 3.0ms preprocess, 80.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fore, 2 hinds, 1 nose, 5 heads, 4 asss, 2 tails, 5 torsos, 79.0ms
# Speed: 4.0ms preprocess, 79.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fores, 2 hinds, 1 nose, 4 heads, 4 asss, 2 tails, 5 torsos, 80.0ms
# Speed: 5.0ms preprocess, 80.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fore, 3 hinds, 2 noses, 5 heads, 4 asss, 2 tails, 5 torsos, 80.0ms
# Speed: 3.0ms preprocess, 80.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fore, 3 hinds, 3 noses, 4 heads, 4 asss, 2 tails, 5 torsos, 80.0ms
# Speed: 5.0ms preprocess, 80.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fore, 3 hinds, 3 noses, 5 heads, 5 asss, 2 tails, 5 torsos, 80.0ms
# Speed: 4.0ms preprocess, 80.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 2 hinds, 2 noses, 4 heads, 5 asss, 3 tails, 5 torsos, 79.0ms
# Speed: 4.0ms preprocess, 79.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 2 hinds, 1 nose, 4 heads, 5 asss, 3 tails, 5 torsos, 80.0ms
# Speed: 3.0ms preprocess, 80.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fore, 2 hinds, 4 heads, 5 asss, 3 tails, 5 torsos, 81.0ms
# Speed: 4.0ms preprocess, 81.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fore, 2 hinds, 5 heads, 5 asss, 3 tails, 5 torsos, 81.0ms
# Speed: 3.0ms preprocess, 81.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fore, 4 hinds, 5 heads, 4 asss, 2 tails, 5 torsos, 82.0ms
# Speed: 3.0ms preprocess, 82.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fore, 4 hinds, 5 heads, 4 asss, 2 tails, 5 torsos, 83.0ms
# Speed: 3.0ms preprocess, 83.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fore, 4 hinds, 3 heads, 4 asss, 2 tails, 6 torsos, 82.0ms
# Speed: 3.0ms preprocess, 82.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fore, 3 hinds, 2 noses, 3 heads, 5 asss, 2 tails, 5 torsos, 83.0ms
# Speed: 3.0ms preprocess, 83.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fores, 2 hinds, 2 noses, 4 heads, 5 asss, 3 tails, 5 torsos, 81.0ms
# Speed: 4.0ms preprocess, 81.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 2 hinds, 1 nose, 4 heads, 5 asss, 3 tails, 5 torsos, 80.0ms
# Speed: 4.0ms preprocess, 80.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 2 hinds, 1 nose, 3 heads, 4 asss, 2 tails, 5 torsos, 80.0ms
# Speed: 3.0ms preprocess, 80.0ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fores, 3 hinds, 1 nose, 3 heads, 5 asss, 3 tails, 5 torsos, 79.0ms
# Speed: 3.0ms preprocess, 79.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fores, 3 hinds, 4 noses, 4 heads, 5 asss, 3 tails, 5 torsos, 79.0ms
# Speed: 4.0ms preprocess, 79.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fores, 3 hinds, 3 noses, 4 heads, 5 asss, 3 tails, 5 torsos, 79.0ms
# Speed: 4.0ms preprocess, 79.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fores, 3 hinds, 3 noses, 4 heads, 5 asss, 3 tails, 5 torsos, 80.0ms
# Speed: 4.0ms preprocess, 80.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fores, 3 hinds, 2 noses, 5 heads, 4 asss, 3 tails, 6 torsos, 80.0ms
# Speed: 4.0ms preprocess, 80.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fores, 3 hinds, 2 noses, 6 heads, 4 asss, 2 tails, 6 torsos, 81.0ms
# Speed: 4.0ms preprocess, 81.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fores, 2 hinds, 3 noses, 5 heads, 5 asss, 2 tails, 5 torsos, 80.0ms
# Speed: 3.0ms preprocess, 80.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fores, 4 hinds, 3 noses, 9 heads, 5 asss, 3 tails, 5 torsos, 80.0ms
# Speed: 4.0ms preprocess, 80.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fores, 3 hinds, 3 noses, 5 heads, 5 asss, 2 tails, 5 torsos, 80.0ms
# Speed: 3.0ms preprocess, 80.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 6 hinds, 3 noses, 5 heads, 5 asss, 2 tails, 5 torsos, 80.0ms
# Speed: 3.0ms preprocess, 80.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 5 hinds, 3 noses, 6 heads, 5 asss, 2 tails, 5 torsos, 81.1ms
# Speed: 4.0ms preprocess, 81.1ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fores, 4 hinds, 3 noses, 5 heads, 4 asss, 2 tails, 5 torsos, 81.1ms
# Speed: 4.0ms preprocess, 81.1ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fore, 4 hinds, 3 noses, 4 heads, 4 asss, 2 tails, 5 torsos, 81.0ms
# Speed: 3.0ms preprocess, 81.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 3 hinds, 3 noses, 5 heads, 4 asss, 2 tails, 5 torsos, 79.0ms
# Speed: 4.0ms preprocess, 79.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 3 hinds, 3 noses, 5 heads, 3 asss, 2 tails, 5 torsos, 78.0ms
# Speed: 4.0ms preprocess, 78.0ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 4 hinds, 1 nose, 3 heads, 4 asss, 1 tail, 5 torsos, 78.0ms
# Speed: 5.0ms preprocess, 78.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 4 hinds, 1 nose, 4 heads, 4 asss, 2 tails, 5 torsos, 77.0ms
# Speed: 3.0ms preprocess, 77.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fores, 3 hinds, 1 nose, 3 heads, 3 asss, 1 tail, 5 torsos, 77.0ms
# Speed: 3.0ms preprocess, 77.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 4 hinds, 1 nose, 4 heads, 3 asss, 2 tails, 6 torsos, 78.0ms
# Speed: 4.0ms preprocess, 78.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 4 hinds, 1 nose, 4 heads, 3 asss, 2 tails, 5 torsos, 78.0ms
# Speed: 4.0ms preprocess, 78.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 5 hinds, 2 noses, 4 heads, 3 asss, 1 tail, 5 torsos, 78.0ms
# Speed: 3.0ms preprocess, 78.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 8 hinds, 1 nose, 4 heads, 3 asss, 1 tail, 5 torsos, 78.0ms
# Speed: 4.0ms preprocess, 78.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 fores, 4 hinds, 2 noses, 4 heads, 2 asss, 1 tail, 5 torsos, 79.1ms
# Speed: 3.0ms preprocess, 79.1ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fores, 4 hinds, 2 noses, 4 heads, 2 asss, 1 tail, 5 torsos, 79.0ms
# Speed: 4.0ms preprocess, 79.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 5 hinds, 2 noses, 4 heads, 3 asss, 1 tail, 5 torsos, 78.0ms
# Speed: 4.0ms preprocess, 78.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 7 hinds, 2 noses, 5 heads, 3 asss, 1 tail, 5 torsos, 79.0ms
# Speed: 3.0ms preprocess, 79.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 6 hinds, 2 noses, 4 heads, 3 asss, 1 tail, 5 torsos, 80.0ms
# Speed: 5.0ms preprocess, 80.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 8 hinds, 2 noses, 4 heads, 3 asss, 4 tails, 5 torsos, 79.0ms
# Speed: 4.0ms preprocess, 79.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 11 hinds, 3 noses, 4 heads, 4 asss, 2 tails, 5 torsos, 80.0ms
# Speed: 3.0ms preprocess, 80.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 9 hinds, 3 noses, 4 heads, 3 asss, 2 tails, 5 torsos, 80.0ms
# Speed: 4.0ms preprocess, 80.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 9 hinds, 1 nose, 4 heads, 3 asss, 2 tails, 5 torsos, 78.0ms
# Speed: 4.0ms preprocess, 78.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fores, 9 hinds, 1 nose, 5 heads, 4 asss, 1 tail, 5 torsos, 77.0ms
# Speed: 3.0ms preprocess, 77.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 8 hinds, 5 heads, 4 asss, 1 tail, 5 torsos, 77.0ms
# Speed: 3.0ms preprocess, 77.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 6 hinds, 6 heads, 3 asss, 1 tail, 5 torsos, 77.0ms
# Speed: 4.0ms preprocess, 77.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 5 hinds, 2 noses, 5 heads, 3 asss, 1 tail, 5 torsos, 77.0ms
# Speed: 4.0ms preprocess, 77.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 5 hinds, 3 noses, 5 heads, 4 asss, 1 tail, 5 torsos, 77.0ms
# Speed: 3.0ms preprocess, 77.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 5 hinds, 1 nose, 4 heads, 2 asss, 1 tail, 5 torsos, 77.0ms
# Speed: 4.0ms preprocess, 77.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 5 hinds, 3 noses, 4 heads, 2 asss, 1 tail, 5 torsos, 77.0ms
# Speed: 4.0ms preprocess, 77.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 5 hinds, 3 noses, 4 heads, 3 asss, 1 tail, 6 torsos, 78.0ms
# Speed: 3.0ms preprocess, 78.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 5 hinds, 2 noses, 5 heads, 7 asss, 1 tail, 5 torsos, 80.0ms
# Speed: 7.8ms preprocess, 80.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 5 hinds, 2 noses, 4 heads, 4 asss, 2 tails, 5 torsos, 78.0ms
# Speed: 4.0ms preprocess, 78.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 6 hinds, 4 noses, 4 heads, 7 asss, 3 tails, 5 torsos, 81.0ms
# Speed: 9.0ms preprocess, 81.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 4 hinds, 3 noses, 4 heads, 4 asss, 3 tails, 5 torsos, 78.0ms
# Speed: 4.0ms preprocess, 78.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 7 hinds, 3 noses, 5 heads, 5 asss, 2 tails, 5 torsos, 77.0ms
# Speed: 4.0ms preprocess, 77.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 6 hinds, 3 noses, 4 heads, 6 asss, 2 tails, 5 torsos, 79.0ms
# Speed: 6.0ms preprocess, 79.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 5 hinds, 3 noses, 3 heads, 5 asss, 1 tail, 5 torsos, 79.0ms
# Speed: 3.0ms preprocess, 79.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 4 hinds, 3 noses, 3 heads, 5 asss, 1 tail, 5 torsos, 76.0ms
# Speed: 4.0ms preprocess, 76.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 5 hinds, 2 noses, 3 heads, 5 asss, 1 tail, 5 torsos, 77.0ms
# Speed: 8.0ms preprocess, 77.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 4 hinds, 2 noses, 3 heads, 5 asss, 1 tail, 5 torsos, 75.0ms
# Speed: 3.0ms preprocess, 75.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 5 hinds, 2 noses, 4 heads, 5 asss, 1 tail, 5 torsos, 74.0ms
# Speed: 4.0ms preprocess, 74.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 5 hinds, 3 noses, 3 heads, 5 asss, 1 tail, 5 torsos, 74.0ms
# Speed: 4.0ms preprocess, 74.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 5 hinds, 3 noses, 3 heads, 5 asss, 1 tail, 5 torsos, 74.0ms
# Speed: 3.0ms preprocess, 74.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 5 hinds, 3 noses, 3 heads, 5 asss, 1 tail, 5 torsos, 74.0ms
# Speed: 3.0ms preprocess, 74.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 5 hinds, 2 noses, 4 heads, 5 asss, 1 tail, 5 torsos, 74.0ms
# Speed: 4.0ms preprocess, 74.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 5 hinds, 2 noses, 5 heads, 5 asss, 1 tail, 5 torsos, 74.0ms
# Speed: 5.0ms preprocess, 74.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 5 hinds, 2 noses, 5 heads, 4 asss, 1 tail, 5 torsos, 73.0ms
# Speed: 4.0ms preprocess, 73.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 5 hinds, 2 noses, 5 heads, 5 asss, 1 tail, 5 torsos, 74.0ms
# Speed: 3.0ms preprocess, 74.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 3 hinds, 1 nose, 4 heads, 5 asss, 3 tails, 5 torsos, 75.0ms
# Speed: 6.0ms preprocess, 75.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 3 hinds, 2 noses, 7 heads, 3 asss, 3 tails, 5 torsos, 74.0ms
# Speed: 3.0ms preprocess, 74.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 5 hinds, 3 noses, 5 heads, 3 asss, 2 tails, 5 torsos, 74.0ms
# Speed: 3.0ms preprocess, 74.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 4 hinds, 3 noses, 6 heads, 3 asss, 2 tails, 5 torsos, 76.0ms
# Speed: 4.0ms preprocess, 76.0ms inference, 5.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 fores, 4 hinds, 3 noses, 5 heads, 3 asss, 2 tails, 5 torsos, 75.0ms
# Speed: 4.0ms preprocess, 75.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 fores, 5 hinds, 2 noses, 4 heads, 3 asss, 2 tails, 5 torsos, 75.0ms
# Speed: 3.0ms preprocess, 75.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 5 hinds, 1 nose, 4 heads, 3 asss, 2 tails, 5 torsos, 76.0ms
# Speed: 5.0ms preprocess, 76.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 5 hinds, 1 nose, 4 heads, 3 asss, 3 tails, 5 torsos, 76.0ms
# Speed: 4.0ms preprocess, 76.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 4 hinds, 2 noses, 5 heads, 4 asss, 3 tails, 5 torsos, 76.0ms
# Speed: 4.0ms preprocess, 76.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 4 hinds, 2 noses, 4 heads, 5 asss, 2 tails, 5 torsos, 76.0ms
# Speed: 4.0ms preprocess, 76.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 6 hinds, 1 nose, 4 heads, 4 asss, 3 tails, 5 torsos, 77.0ms
# Speed: 3.0ms preprocess, 77.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fores, 5 hinds, 2 noses, 4 heads, 5 asss, 4 tails, 5 torsos, 77.0ms
# Speed: 4.0ms preprocess, 77.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 3 hinds, 2 noses, 5 heads, 4 asss, 4 tails, 5 torsos, 78.0ms
# Speed: 4.0ms preprocess, 78.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 4 hinds, 1 nose, 5 heads, 4 asss, 3 tails, 5 torsos, 82.0ms
# Speed: 9.0ms preprocess, 82.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 4 hinds, 2 noses, 5 heads, 4 asss, 2 tails, 5 torsos, 81.0ms
# Speed: 3.0ms preprocess, 81.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 4 hinds, 1 nose, 5 heads, 4 asss, 3 tails, 5 torsos, 80.0ms
# Speed: 4.0ms preprocess, 80.0ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 4 hinds, 2 noses, 3 heads, 4 asss, 3 tails, 5 torsos, 84.0ms
# Speed: 7.8ms preprocess, 84.0ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 4 hinds, 2 noses, 5 heads, 5 asss, 2 tails, 5 torsos, 85.0ms
# Speed: 3.0ms preprocess, 85.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 6 hinds, 3 noses, 4 heads, 3 asss, 2 tails, 5 torsos, 81.0ms
# Speed: 4.0ms preprocess, 81.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 6 hinds, 2 noses, 5 heads, 3 asss, 3 tails, 5 torsos, 80.0ms
# Speed: 4.0ms preprocess, 80.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 7 hinds, 2 noses, 4 heads, 4 asss, 2 tails, 5 torsos, 81.0ms
# Speed: 4.0ms preprocess, 81.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 7 hinds, 2 noses, 4 heads, 4 asss, 1 tail, 5 torsos, 79.0ms
# Speed: 4.0ms preprocess, 79.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 5 hinds, 3 noses, 4 heads, 4 asss, 4 tails, 5 torsos, 80.0ms
# Speed: 9.0ms preprocess, 80.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 5 hinds, 1 nose, 4 heads, 4 asss, 3 tails, 5 torsos, 80.0ms
# Speed: 4.0ms preprocess, 80.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 fores, 7 hinds, 2 noses, 4 heads, 4 asss, 3 tails, 5 torsos, 80.0ms
# Speed: 3.0ms preprocess, 80.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 fores, 8 hinds, 3 noses, 4 heads, 3 asss, 3 tails, 5 torsos, 79.0ms
# Speed: 4.0ms preprocess, 79.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 fores, 8 hinds, 3 noses, 4 heads, 3 asss, 3 tails, 5 torsos, 80.0ms
# Speed: 3.0ms preprocess, 80.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 4 hinds, 4 noses, 6 heads, 4 asss, 4 tails, 5 torsos, 83.0ms
# Speed: 3.0ms preprocess, 83.0ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 5 hinds, 3 noses, 4 heads, 4 asss, 4 tails, 5 torsos, 81.0ms
# Speed: 3.0ms preprocess, 81.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 4 hinds, 1 nose, 5 heads, 4 asss, 4 tails, 5 torsos, 80.0ms
# Speed: 5.0ms preprocess, 80.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 fores, 7 hinds, 1 nose, 5 heads, 3 asss, 2 tails, 5 torsos, 80.0ms
# Speed: 3.0ms preprocess, 80.0ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 fores, 6 hinds, 2 noses, 5 heads, 5 asss, 3 tails, 5 torsos, 81.0ms
# Speed: 4.0ms preprocess, 81.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 4 hinds, 3 noses, 4 heads, 5 asss, 6 tails, 5 torsos, 80.0ms
# Speed: 4.0ms preprocess, 80.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 6 hinds, 3 noses, 6 heads, 6 asss, 4 tails, 5 torsos, 80.0ms
# Speed: 7.0ms preprocess, 80.0ms inference, 7.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 8 hinds, 3 noses, 5 heads, 5 asss, 5 tails, 5 torsos, 80.0ms
# Speed: 3.0ms preprocess, 80.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 8 hinds, 2 noses, 4 heads, 4 asss, 3 tails, 5 torsos, 80.0ms
# Speed: 4.0ms preprocess, 80.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 8 hinds, 2 noses, 4 heads, 4 asss, 4 tails, 5 torsos, 81.0ms
# Speed: 7.0ms preprocess, 81.0ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 7 hinds, 3 noses, 4 heads, 4 asss, 3 tails, 5 torsos, 80.0ms
# Speed: 7.0ms preprocess, 80.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 9 hinds, 3 noses, 4 heads, 4 asss, 3 tails, 5 torsos, 79.0ms
# Speed: 4.0ms preprocess, 79.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 5 hinds, 3 noses, 4 heads, 3 asss, 2 tails, 5 torsos, 79.0ms
# Speed: 4.0ms preprocess, 79.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 5 hinds, 1 nose, 4 heads, 3 asss, 2 tails, 5 torsos, 78.0ms
# Speed: 4.0ms preprocess, 78.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 fores, 5 hinds, 1 nose, 5 heads, 4 asss, 3 tails, 5 torsos, 78.0ms
# Speed: 4.0ms preprocess, 78.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 5 hinds, 3 noses, 4 heads, 3 asss, 3 tails, 5 torsos, 80.0ms
# Speed: 4.0ms preprocess, 80.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 fores, 5 hinds, 3 noses, 4 heads, 3 asss, 2 tails, 5 torsos, 80.0ms
# Speed: 4.0ms preprocess, 80.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 fores, 6 hinds, 3 noses, 6 heads, 3 asss, 2 tails, 5 torsos, 81.0ms
# Speed: 4.0ms preprocess, 81.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 4 hinds, 4 noses, 4 heads, 5 asss, 2 tails, 5 torsos, 79.0ms
# Speed: 3.0ms preprocess, 79.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 4 hinds, 2 noses, 4 heads, 5 asss, 2 tails, 5 torsos, 78.0ms
# Speed: 4.0ms preprocess, 78.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 4 hinds, 3 noses, 5 heads, 3 asss, 2 tails, 5 torsos, 78.0ms
# Speed: 4.0ms preprocess, 78.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 5 hinds, 3 noses, 4 heads, 3 asss, 2 tails, 5 torsos, 78.0ms
# Speed: 3.0ms preprocess, 78.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 5 hinds, 2 noses, 4 heads, 2 asss, 2 tails, 5 torsos, 78.1ms
# Speed: 5.0ms preprocess, 78.1ms inference, 3.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 fores, 5 hinds, 3 noses, 4 heads, 2 asss, 2 tails, 5 torsos, 77.0ms
# Speed: 3.0ms preprocess, 77.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 fores, 6 hinds, 2 noses, 4 heads, 2 asss, 2 tails, 5 torsos, 77.0ms
# Speed: 3.0ms preprocess, 77.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 fores, 6 hinds, 2 noses, 4 heads, 2 asss, 2 tails, 5 torsos, 77.0ms
# Speed: 4.0ms preprocess, 77.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 fores, 3 hinds, 1 nose, 5 heads, 3 asss, 2 tails, 5 torsos, 77.0ms
# Speed: 4.0ms preprocess, 77.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 6 hinds, 2 noses, 4 heads, 3 asss, 2 tails, 5 torsos, 78.0ms
# Speed: 4.0ms preprocess, 78.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 6 hinds, 2 noses, 4 heads, 4 asss, 3 tails, 5 torsos, 79.0ms
# Speed: 4.0ms preprocess, 79.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 fores, 6 hinds, 2 noses, 4 heads, 5 asss, 2 tails, 5 torsos, 78.0ms
# Speed: 4.0ms preprocess, 78.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 7 hinds, 3 noses, 4 heads, 4 asss, 1 tail, 5 torsos, 79.0ms
# Speed: 4.0ms preprocess, 79.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 5 hinds, 2 noses, 4 heads, 4 asss, 1 tail, 5 torsos, 78.0ms
# Speed: 4.0ms preprocess, 78.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 5 hinds, 2 noses, 4 heads, 4 asss, 1 tail, 5 torsos, 78.0ms
# Speed: 3.0ms preprocess, 78.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 9 hinds, 2 noses, 5 heads, 4 asss, 1 tail, 6 torsos, 79.0ms
# Speed: 4.0ms preprocess, 79.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 10 hinds, 3 noses, 5 heads, 4 asss, 6 torsos, 78.0ms
# Speed: 3.0ms preprocess, 78.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 8 hinds, 2 noses, 5 heads, 2 asss, 1 tail, 5 torsos, 78.0ms
# Speed: 4.0ms preprocess, 78.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 8 hinds, 2 noses, 5 heads, 2 asss, 2 tails, 5 torsos, 78.0ms
# Speed: 4.0ms preprocess, 78.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 8 hinds, 2 noses, 5 heads, 2 asss, 2 tails, 6 torsos, 79.0ms
# Speed: 4.0ms preprocess, 79.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 9 hinds, 2 noses, 5 heads, 3 asss, 3 tails, 6 torsos, 78.0ms
# Speed: 4.0ms preprocess, 78.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 9 hinds, 2 noses, 5 heads, 3 asss, 2 tails, 5 torsos, 75.0ms
# Speed: 4.0ms preprocess, 75.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 9 hinds, 2 noses, 5 heads, 4 asss, 1 tail, 6 torsos, 75.0ms
# Speed: 4.0ms preprocess, 75.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 9 hinds, 2 noses, 4 heads, 5 asss, 1 tail, 5 torsos, 75.0ms
# Speed: 4.0ms preprocess, 75.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 9 hinds, 2 noses, 4 heads, 4 asss, 2 tails, 5 torsos, 75.0ms
# Speed: 4.0ms preprocess, 75.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fores, 8 hinds, 3 noses, 4 heads, 4 asss, 3 tails, 5 torsos, 75.0ms
# Speed: 4.0ms preprocess, 75.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 7 hinds, 2 noses, 4 heads, 6 asss, 1 tail, 5 torsos, 75.0ms
# Speed: 5.0ms preprocess, 75.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 7 hinds, 1 nose, 4 heads, 6 asss, 1 tail, 5 torsos, 76.0ms
# Speed: 5.0ms preprocess, 76.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 7 hinds, 1 nose, 4 heads, 4 asss, 1 tail, 5 torsos, 75.0ms
# Speed: 4.0ms preprocess, 75.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 8 hinds, 2 noses, 5 heads, 3 asss, 1 tail, 6 torsos, 77.0ms
# Speed: 5.0ms preprocess, 77.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 fores, 7 hinds, 1 nose, 5 heads, 5 asss, 1 tail, 5 torsos, 77.0ms
# Speed: 4.0ms preprocess, 77.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fores, 7 hinds, 1 nose, 5 heads, 4 asss, 1 tail, 6 torsos, 77.0ms
# Speed: 4.0ms preprocess, 77.0ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fores, 7 hinds, 2 noses, 5 heads, 4 asss, 1 tail, 5 torsos, 76.0ms
# Speed: 4.0ms preprocess, 76.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 7 hinds, 1 nose, 5 heads, 5 asss, 1 tail, 5 torsos, 77.9ms
# Speed: 3.1ms preprocess, 77.9ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 8 hinds, 1 nose, 5 heads, 5 asss, 2 tails, 5 torsos, 78.0ms
# Speed: 4.0ms preprocess, 78.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 8 hinds, 1 nose, 5 heads, 4 asss, 3 tails, 5 torsos, 78.0ms
# Speed: 4.0ms preprocess, 78.0ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 8 hinds, 1 nose, 5 heads, 4 asss, 1 tail, 5 torsos, 78.0ms
# Speed: 4.0ms preprocess, 78.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 8 hinds, 1 nose, 5 heads, 4 asss, 2 tails, 6 torsos, 79.0ms
# Speed: 4.0ms preprocess, 79.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 fores, 8 hinds, 5 heads, 4 asss, 2 tails, 5 torsos, 79.0ms
# Speed: 3.0ms preprocess, 79.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 fores, 5 hinds, 5 heads, 3 asss, 1 tail, 5 torsos, 80.0ms
# Speed: 3.0ms preprocess, 80.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 fores, 6 hinds, 1 nose, 5 heads, 2 asss, 6 torsos, 80.0ms
# Speed: 3.0ms preprocess, 80.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 5 hinds, 2 noses, 5 heads, 4 asss, 1 tail, 5 torsos, 81.0ms
# Speed: 3.0ms preprocess, 81.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 5 hinds, 1 nose, 6 heads, 4 asss, 1 tail, 5 torsos, 80.0ms
# Speed: 3.0ms preprocess, 80.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fores, 7 hinds, 1 nose, 5 heads, 4 asss, 1 tail, 5 torsos, 79.0ms
# Speed: 4.0ms preprocess, 79.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 6 hinds, 3 noses, 4 heads, 4 asss, 4 tails, 6 torsos, 79.0ms
# Speed: 4.0ms preprocess, 79.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 8 hinds, 2 noses, 4 heads, 4 asss, 5 tails, 6 torsos, 80.1ms
# Speed: 4.0ms preprocess, 80.1ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 8 hinds, 2 noses, 4 heads, 4 asss, 4 tails, 5 torsos, 80.0ms
# Speed: 4.0ms preprocess, 80.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 7 hinds, 3 noses, 4 heads, 4 asss, 3 tails, 5 torsos, 80.0ms
# Speed: 4.0ms preprocess, 80.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fore, 9 hinds, 3 noses, 4 heads, 4 asss, 3 tails, 5 torsos, 79.0ms
# Speed: 3.0ms preprocess, 79.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fore, 7 hinds, 1 nose, 4 heads, 4 asss, 3 tails, 5 torsos, 80.0ms
# Speed: 3.0ms preprocess, 80.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fores, 7 hinds, 2 noses, 4 heads, 3 asss, 3 tails, 5 torsos, 80.0ms
# Speed: 4.0ms preprocess, 80.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fores, 7 hinds, 1 nose, 4 heads, 3 asss, 5 tails, 5 torsos, 83.0ms
# Speed: 4.0ms preprocess, 83.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fores, 8 hinds, 1 nose, 3 heads, 5 asss, 4 tails, 5 torsos, 82.0ms
# Speed: 4.0ms preprocess, 82.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 8 hinds, 1 nose, 8 heads, 2 asss, 6 tails, 5 torsos, 82.1ms
# Speed: 3.0ms preprocess, 82.1ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 8 hinds, 3 noses, 4 heads, 3 asss, 6 tails, 5 torsos, 80.0ms
# Speed: 4.0ms preprocess, 80.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 7 hinds, 3 noses, 4 heads, 3 asss, 5 tails, 5 torsos, 80.0ms
# Speed: 4.0ms preprocess, 80.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 6 hinds, 3 noses, 5 heads, 4 asss, 7 tails, 5 torsos, 80.0ms
# Speed: 3.0ms preprocess, 80.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 fores, 5 hinds, 2 noses, 5 heads, 4 asss, 3 tails, 5 torsos, 80.0ms
# Speed: 4.0ms preprocess, 80.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 4 hinds, 3 noses, 5 heads, 4 asss, 2 tails, 5 torsos, 81.0ms
# Speed: 7.0ms preprocess, 81.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 4 hinds, 1 nose, 6 heads, 3 asss, 2 tails, 5 torsos, 79.0ms
# Speed: 4.0ms preprocess, 79.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 2 hinds, 6 heads, 3 asss, 1 tail, 5 torsos, 79.0ms
# Speed: 4.0ms preprocess, 79.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fores, 3 hinds, 5 heads, 4 asss, 2 tails, 5 torsos, 80.0ms
# Speed: 4.0ms preprocess, 80.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fores, 3 hinds, 5 heads, 4 asss, 3 tails, 5 torsos, 80.0ms
# Speed: 4.0ms preprocess, 80.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 2 hinds, 5 heads, 3 asss, 3 tails, 5 torsos, 83.0ms
# Speed: 4.0ms preprocess, 83.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fores, 3 hinds, 1 nose, 6 heads, 3 asss, 2 tails, 5 torsos, 81.0ms
# Speed: 3.0ms preprocess, 81.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 hinds, 4 heads, 3 asss, 2 tails, 5 torsos, 81.0ms
# Speed: 4.0ms preprocess, 81.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 2 hinds, 4 heads, 2 asss, 2 tails, 5 torsos, 80.0ms
# Speed: 4.0ms preprocess, 80.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 2 hinds, 5 heads, 2 asss, 2 tails, 5 torsos, 80.0ms
# Speed: 4.0ms preprocess, 80.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 4 hinds, 6 heads, 2 asss, 2 tails, 5 torsos, 80.0ms
# Speed: 4.0ms preprocess, 80.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fore, 3 hinds, 5 heads, 2 asss, 1 tail, 5 torsos, 79.0ms
# Speed: 4.0ms preprocess, 79.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fores, 4 hinds, 2 noses, 8 heads, 2 asss, 1 tail, 5 torsos, 80.0ms
# Speed: 4.0ms preprocess, 80.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 3 hinds, 2 noses, 5 heads, 3 asss, 2 tails, 5 torsos, 80.0ms
# Speed: 3.0ms preprocess, 80.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 3 hinds, 2 noses, 6 heads, 4 asss, 2 tails, 5 torsos, 80.0ms
# Speed: 5.0ms preprocess, 80.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fore, 2 hinds, 5 heads, 4 asss, 2 tails, 5 torsos, 80.0ms
# Speed: 3.0ms preprocess, 80.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hinds, 1 nose, 5 heads, 3 asss, 3 tails, 5 torsos, 80.0ms
# Speed: 4.0ms preprocess, 80.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hinds, 5 heads, 4 asss, 4 tails, 5 torsos, 79.0ms
# Speed: 4.0ms preprocess, 79.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fores, 2 hinds, 2 noses, 4 heads, 3 asss, 3 tails, 5 torsos, 79.0ms
# Speed: 5.0ms preprocess, 79.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fores, 2 hinds, 3 noses, 4 heads, 3 asss, 3 tails, 5 torsos, 79.0ms
# Speed: 4.0ms preprocess, 79.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# ...
#
# 0: 384x640 6 fores, 6 hinds, 3 noses, 5 heads, 4 asss, 1 tail, 5 torsos, 80.0ms
# Speed: 3.0ms preprocess, 80.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 3 hinds, 3 noses, 5 heads, 3 asss, 2 tails, 5 torsos, 79.0ms
# Speed: 3.0ms preprocess, 79.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 4 hinds, 2 noses, 5 heads, 3 asss, 3 tails, 5 torsos, 78.0ms
# Speed: 4.0ms preprocess, 78.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 5 hinds, 2 noses, 4 heads, 3 asss, 1 tail, 5 torsos, 78.0ms
# Speed: 5.0ms preprocess, 78.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 4 hinds, 2 noses, 4 heads, 3 asss, 1 tail, 5 torsos, 78.0ms
# Speed: 4.0ms preprocess, 78.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 4 hinds, 2 noses, 6 heads, 4 asss, 2 tails, 5 torsos, 78.0ms
# Speed: 3.0ms preprocess, 78.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 fores, 5 hinds, 3 noses, 5 heads, 6 asss, 1 tail, 5 torsos, 79.0ms
# Speed: 3.0ms preprocess, 79.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fores, 4 hinds, 3 noses, 5 heads, 6 asss, 5 torsos, 79.0ms
# Speed: 3.0ms preprocess, 79.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 5 hinds, 3 noses, 5 heads, 5 asss, 5 torsos, 79.0ms
# Speed: 3.0ms preprocess, 79.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 3 hinds, 3 noses, 6 heads, 4 asss, 5 torsos, 80.0ms
# Speed: 3.0ms preprocess, 80.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 3 hinds, 3 noses, 5 heads, 3 asss, 2 tails, 5 torsos, 80.0ms
# Speed: 4.0ms preprocess, 80.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 5 hinds, 3 noses, 6 heads, 3 asss, 2 tails, 5 torsos, 80.0ms
# Speed: 4.0ms preprocess, 80.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 5 hinds, 3 noses, 5 heads, 3 asss, 3 tails, 5 torsos, 80.0ms
# Speed: 4.0ms preprocess, 80.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 fores, 9 hinds, 2 noses, 6 heads, 3 asss, 2 tails, 5 torsos, 80.0ms
# Speed: 4.0ms preprocess, 80.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 fores, 7 hinds, 3 noses, 5 heads, 4 asss, 3 tails, 5 torsos, 80.0ms
# Speed: 4.0ms preprocess, 80.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 fores, 7 hinds, 3 noses, 4 heads, 4 asss, 2 tails, 5 torsos, 80.0ms
# Speed: 4.0ms preprocess, 80.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 7 hinds, 3 noses, 4 heads, 3 asss, 1 tail, 5 torsos, 79.0ms
# Speed: 4.0ms preprocess, 79.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 fores, 7 hinds, 3 noses, 6 heads, 3 asss, 2 tails, 5 torsos, 80.0ms
# Speed: 3.0ms preprocess, 80.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 fores, 7 hinds, 2 noses, 4 heads, 3 asss, 3 tails, 5 torsos, 81.0ms
# Speed: 4.0ms preprocess, 81.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 fores, 7 hinds, 2 noses, 4 heads, 3 asss, 4 tails, 5 torsos, 80.0ms
# Speed: 4.0ms preprocess, 80.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 fores, 7 hinds, 4 noses, 5 heads, 4 asss, 4 tails, 5 torsos, 82.0ms
# Speed: 4.0ms preprocess, 82.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 fores, 4 hinds, 2 noses, 5 heads, 3 asss, 2 tails, 5 torsos, 84.0ms
# Speed: 3.0ms preprocess, 84.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 5 hinds, 2 noses, 6 heads, 3 asss, 3 tails, 5 torsos, 83.0ms
# Speed: 4.0ms preprocess, 83.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 3 hinds, 1 nose, 5 heads, 4 asss, 2 tails, 5 torsos, 82.0ms
# Speed: 5.0ms preprocess, 82.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 fores, 3 hinds, 1 nose, 4 heads, 4 asss, 4 tails, 5 torsos, 80.0ms
# Speed: 3.0ms preprocess, 80.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 2 hinds, 3 noses, 4 heads, 3 asss, 3 tails, 5 torsos, 80.0ms
# Speed: 4.0ms preprocess, 80.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 2 hinds, 3 noses, 4 heads, 4 asss, 3 tails, 5 torsos, 79.0ms
# Speed: 4.0ms preprocess, 79.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 fores, 3 hinds, 2 noses, 4 heads, 3 asss, 3 tails, 5 torsos, 80.0ms
# Speed: 4.0ms preprocess, 80.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 fores, 2 hinds, 2 noses, 5 heads, 3 asss, 2 tails, 5 torsos, 80.0ms
# Speed: 3.0ms preprocess, 80.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 2 hinds, 2 noses, 4 heads, 3 asss, 1 tail, 5 torsos, 80.0ms
# Speed: 3.0ms preprocess, 80.0ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 2 hinds, 2 noses, 4 heads, 3 asss, 2 tails, 5 torsos, 79.0ms
# Speed: 3.0ms preprocess, 79.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 2 hinds, 2 noses, 4 heads, 3 asss, 2 tails, 5 torsos, 79.0ms
# Speed: 4.0ms preprocess, 79.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 2 hinds, 2 noses, 4 heads, 3 asss, 1 tail, 5 torsos, 79.0ms
# Speed: 3.0ms preprocess, 79.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 2 hinds, 2 noses, 4 heads, 3 asss, 3 tails, 5 torsos, 79.0ms
# Speed: 3.0ms preprocess, 79.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 2 hinds, 2 noses, 4 heads, 4 asss, 3 tails, 5 torsos, 78.0ms
# Speed: 4.0ms preprocess, 78.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 fores, 2 hinds, 3 noses, 4 heads, 4 asss, 2 tails, 5 torsos, 79.0ms
# Speed: 4.0ms preprocess, 79.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 fores, 2 hinds, 3 noses, 6 heads, 3 asss, 2 tails, 5 torsos, 80.0ms
# Speed: 3.0ms preprocess, 80.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 fores, 3 hinds, 2 noses, 6 heads, 3 asss, 2 tails, 5 torsos, 82.0ms
# Speed: 3.0ms preprocess, 82.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 4 hinds, 1 nose, 5 heads, 3 asss, 2 tails, 5 torsos, 82.0ms
# Speed: 4.0ms preprocess, 82.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 4 hinds, 1 nose, 4 heads, 3 asss, 4 tails, 5 torsos, 82.0ms
# Speed: 4.0ms preprocess, 82.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 4 hinds, 2 noses, 6 heads, 3 asss, 4 tails, 5 torsos, 83.0ms
# Speed: 3.0ms preprocess, 83.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 4 hinds, 2 noses, 6 heads, 3 asss, 5 tails, 5 torsos, 81.1ms
# Speed: 4.0ms preprocess, 81.1ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 4 hinds, 2 noses, 5 heads, 3 asss, 4 tails, 5 torsos, 80.0ms
# Speed: 4.0ms preprocess, 80.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 4 hinds, 1 nose, 6 heads, 3 asss, 3 tails, 5 torsos, 80.0ms
# Speed: 4.0ms preprocess, 80.0ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fores, 3 hinds, 1 nose, 4 heads, 4 asss, 2 tails, 5 torsos, 79.0ms
# Speed: 4.0ms preprocess, 79.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fore, 4 hinds, 1 nose, 5 heads, 4 asss, 1 tail, 5 torsos, 79.9ms
# Speed: 5.1ms preprocess, 79.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fores, 2 hinds, 1 nose, 6 heads, 2 asss, 1 tail, 5 torsos, 80.0ms
# Speed: 4.0ms preprocess, 80.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fores, 2 hinds, 1 nose, 5 heads, 2 asss, 1 tail, 5 torsos, 80.0ms
# Speed: 3.0ms preprocess, 80.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fore, 2 hinds, 6 heads, 2 asss, 1 tail, 5 torsos, 80.0ms
# Speed: 3.0ms preprocess, 80.0ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 fore, 2 hinds, 6 heads, 3 asss, 1 tail, 5 torsos, 80.0ms
# Speed: 4.0ms preprocess, 80.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 2 hinds, 5 heads, 2 asss, 1 tail, 5 torsos, 81.0ms
# Speed: 4.0ms preprocess, 81.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 2 hinds, 1 nose, 5 heads, 2 asss, 1 tail, 5 torsos, 80.0ms
# Speed: 3.0ms preprocess, 80.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hinds, 2 noses, 6 heads, 2 asss, 1 tail, 5 torsos, 79.0ms
# Speed: 3.0ms preprocess, 79.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 hinds, 2 noses, 6 heads, 2 asss, 1 tail, 5 torsos, 79.0ms
# Speed: 4.0ms preprocess, 79.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 2 hinds, 1 nose, 6 heads, 2 asss, 2 tails, 5 torsos, 80.0ms
# Speed: 4.0ms preprocess, 80.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 3 hinds, 3 noses, 7 heads, 4 asss, 4 tails, 5 torsos, 80.3ms
# Speed: 4.0ms preprocess, 80.3ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 fores, 4 hinds, 3 noses, 6 heads, 4 asss, 3 tails, 5 torsos, 83.0ms
# Speed: 3.0ms preprocess, 83.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 fores, 6 hinds, 3 noses, 4 heads, 2 asss, 3 tails, 5 torsos, 82.0ms
# Speed: 3.0ms preprocess, 82.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 8 hinds, 3 noses, 4 heads, 5 asss, 3 tails, 5 torsos, 83.0ms
# Speed: 4.0ms preprocess, 83.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 8 hinds, 2 noses, 4 heads, 4 asss, 4 tails, 5 torsos, 82.0ms
# Speed: 3.0ms preprocess, 82.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 10 hinds, 3 noses, 4 heads, 4 asss, 4 tails, 5 torsos, 81.0ms
# Speed: 4.0ms preprocess, 81.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 fores, 8 hinds, 2 noses, 4 heads, 5 asss, 5 tails, 5 torsos, 80.0ms
# Speed: 4.0ms preprocess, 80.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 8 hinds, 2 noses, 4 heads, 5 asss, 4 tails, 5 torsos, 80.0ms
# Speed: 4.0ms preprocess, 80.0ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 7 hinds, 1 nose, 4 heads, 3 asss, 4 tails, 5 torsos, 79.0ms
# Speed: 4.0ms preprocess, 79.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 fores, 6 hinds, 3 noses, 4 heads, 3 asss, 5 tails, 5 torsos, 80.0ms
# Speed: 5.0ms preprocess, 80.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 fores, 4 hinds, 3 noses, 5 heads, 3 asss, 4 tails, 5 torsos, 79.0ms
# Speed: 4.0ms preprocess, 79.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 fores, 7 hinds, 3 noses, 5 heads, 4 asss, 3 tails, 5 torsos, 79.0ms
# Speed: 4.0ms preprocess, 79.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 fores, 4 hinds, 3 noses, 4 heads, 3 asss, 3 tails, 5 torsos, 80.0ms
# Speed: 4.0ms preprocess, 80.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 fores, 5 hinds, 3 noses, 4 heads, 3 asss, 3 tails, 5 torsos, 79.0ms
# Speed: 3.0ms preprocess, 79.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 5 hinds, 3 noses, 4 heads, 3 asss, 3 tails, 5 torsos, 82.0ms
# Speed: 4.0ms preprocess, 82.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 4 hinds, 2 noses, 4 heads, 4 asss, 2 tails, 5 torsos, 83.0ms
# Speed: 5.0ms preprocess, 83.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 4 hinds, 2 noses, 4 heads, 4 asss, 2 tails, 5 torsos, 83.1ms
# Speed: 3.0ms preprocess, 83.1ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 5 hinds, 3 noses, 4 heads, 5 asss, 2 tails, 5 torsos, 81.0ms
# Speed: 3.0ms preprocess, 81.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 5 hinds, 3 noses, 5 heads, 4 asss, 2 tails, 5 torsos, 80.0ms
# Speed: 4.0ms preprocess, 80.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 5 hinds, 3 noses, 5 heads, 4 asss, 2 tails, 5 torsos, 80.0ms
# Speed: 3.0ms preprocess, 80.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 fores, 5 hinds, 4 noses, 4 heads, 5 asss, 2 tails, 5 torsos, 79.0ms
# Speed: 3.0ms preprocess, 79.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 6 hinds, 1 nose, 6 heads, 4 asss, 1 tail, 5 torsos, 79.0ms
# Speed: 4.0ms preprocess, 79.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 6 hinds, 1 nose, 6 heads, 4 asss, 1 tail, 5 torsos, 79.0ms
# Speed: 4.0ms preprocess, 79.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 6 hinds, 2 noses, 5 heads, 4 asss, 1 tail, 5 torsos, 80.0ms
# Speed: 3.0ms preprocess, 80.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 6 hinds, 2 noses, 5 heads, 4 asss, 1 tail, 5 torsos, 80.0ms
# Speed: 4.0ms preprocess, 80.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 fores, 6 hinds, 1 nose, 5 heads, 4 asss, 1 tail, 5 torsos, 80.0ms
# Speed: 3.0ms preprocess, 80.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 fores, 6 hinds, 2 noses, 5 heads, 4 asss, 1 tail, 5 torsos, 80.0ms
# Speed: 3.0ms preprocess, 80.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 fores, 6 hinds, 2 noses, 5 heads, 3 asss, 2 tails, 5 torsos, 79.0ms
# Speed: 4.0ms preprocess, 79.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 fores, 5 hinds, 2 noses, 5 heads, 3 asss, 2 tails, 5 torsos, 79.0ms
# Speed: 3.0ms preprocess, 79.0ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 fores, 5 hinds, 1 nose, 5 heads, 3 asss, 2 tails, 5 torsos, 80.0ms
# Speed: 4.0ms preprocess, 80.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 fores, 5 hinds, 5 heads, 3 asss, 2 tails, 5 torsos, 80.0ms
# Speed: 5.0ms preprocess, 80.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 5 hinds, 2 noses, 4 heads, 2 asss, 2 tails, 5 torsos, 81.0ms
# Speed: 4.0ms preprocess, 81.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 6 hinds, 2 noses, 4 heads, 2 asss, 2 tails, 5 torsos, 81.0ms
# Speed: 3.0ms preprocess, 81.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 fores, 7 hinds, 3 noses, 4 heads, 4 asss, 2 tails, 5 torsos, 79.0ms
# Speed: 4.0ms preprocess, 79.0ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 fores, 7 hinds, 2 noses, 4 heads, 3 asss, 3 tails, 5 torsos, 78.0ms
# Speed: 4.0ms preprocess, 78.0ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)

# %%
# Center point version
import cv2
from ultralytics import YOLO
from collections import defaultdict
import numpy as np

# Load the YOLOv8 model
model = YOLO('./weights/20240106_best_weight_yolov8_640.pt')

# Open the video file
input_video_name = 'byun_data_1200f.mp4'
output_video_name = 'byun_data_1200f_output_track.mp4'
video_path = './'+ input_video_name
cap = cv2.VideoCapture(video_path)

# Define the codec and create VideoWriter object to save the video
fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Codec for .mp4 files
fps = cap.get(cv2.CAP_PROP_FPS)  # Use the same FPS as the source video
frame_width = int(cap.get(3))  # Width of the frames in the video
frame_height = int(cap.get(4))  # Height of the frames in the video
out = cv2.VideoWriter(output_video_name, fourcc, fps, (frame_width, frame_height))

# Store the track history
track_history = defaultdict(lambda: [])

# Loop through the video frames
while cap.isOpened():
    # Read a frame from the video
    success, frame = cap.read()

    if success:
        # Run YOLOv8 tracking on the frame, persisting tracks between frames
        # results = model.track(frame, persist=True)
        results = model(frame)
        
        # Get the boxes and track IDs
        boxes = results[0].boxes.xywh.cpu()
        track_ids = results[0].boxes.id.int().cpu().tolist()

        # Visualize the results on the frame
        annotated_frame = results[0].plot(line_width = 1, labels = False)

        # Plot the tracks
        for box, track_id in zip(boxes, track_ids):
            x, y, w, h = box
            track = track_history[track_id]
            track.append((float(x), float(y)))  # x, y center point
            if len(track) > 30:  # retain 90 tracks for 90 frames
                track.pop(0)

            # Draw the tracking lines
            points = np.hstack(track).astype(np.int32).reshape((-1, 1, 2))
            cv2.polylines(annotated_frame, [points], isClosed=False, color=(230, 230, 230), thickness=10)

        # Display the annotated frame
        # cv2.imshow("YOLOv8 Tracking", annotated_frame)
        
        # Write the annotated frame to the output video file
        out.write(annotated_frame)
        
        # Break the loop if 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        # Break the loop if the end of the video is reached
        break

# Release the video capture object and close the display window
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 3 fores, 4 hinds, 5 heads, 4 asss, 2 tails, 5 torsos, 109.0ms
# Speed: 2.0ms preprocess, 109.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[35], line 38
#      36 # Get the boxes and track IDs
#      37 boxes = results[0].boxes.xywh.cpu()
# ---> 38 track_ids = results[0].boxes.id.int().cpu().tolist()
#      40 # Visualize the results on the frame
#      41 annotated_frame = results[0].plot(line_width = 1, labels = False)
#
# AttributeError: 'NoneType' object has no attribute 'int'

# %%
import cv2
from ultralytics import YOLO
import time
import sp_modules as sp
import numpy as np

# Load the YOLOv8 model
model = YOLO('./weights/20240106_best_weight_yolov8_640.pt')

# Open the video file
# file_path = 'E:/Raw data/datasets/AVATAR/'
# file_name = 'Hab_01_1200f'
file_path = 'D:/spkim/data/20241114_40Hz_test/20241114_40Hz_test/'
file_name = 'C_20Hz_Bandi_20fps'
input_video_name = file_path + file_name + '.mp4'
output_video_name = file_path + file_name + '_output.mp4'

cap = cv2.VideoCapture(input_video_name)

# Define the codec and create VideoWriter object to save the video
fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Codec for .mp4 files
fps = cap.get(cv2.CAP_PROP_FPS)  # Use the same FPS as the source video
frame_total = int(cap.get(cv2.CAP_PROP_FRAME_COUNT)) # Use the total frame to estimate the time
frame_width = int(cap.get(3))  # Width of the frames in the video
frame_height = int(cap.get(4))  # Height of the frames in the video
frame_width_resize = 800
frame_height_resize = 600

out = cv2.VideoWriter(output_video_name, fourcc, fps, (frame_width, frame_height))
# out = cv2.VideoWriter(output_video_name, fourcc, fps, (frame_width_resize, frame_height_resize))
current_frame=0

# Color code setting for center-point
color_code = {
    "red": (0, 0, 255),
    "orange": (0, 165, 255),
    "yellow": (0, 255, 255),
    "green": (0, 128, 0),
    "blue": (255, 0, 0),
    "skyblue": (235, 206, 135),
    "purple": (128, 0, 128),
    "black": (0, 0, 0),
    "pink": (255, 192, 203)
}
color_order = ["red", "orange", "yellow", "green", "blue", "skyblue", "purple", "black", "pink"]
output = []

#To match darknet (YOLOv4), #4, 5: forelimb / #6, 7: hindlimb
rearrange = [4, 6, 0, 1, 3, 8, 2]
# Five areas from captured frame (x1, y1, x2, y2)
area = [
    [ 1, 1, 1200, 1000],
    [ 1201, 1, 2400, 1000],
    [ 2401, 1, 3600, 1200],
    [ 1, 1001, 1200, 2016],
    [ 1201, 1001, 2400, 2016]
]
raw_coordinates = [0] * 135
while cap.isOpened():
    start_time = time.time() # Time measurement
    success, frame = cap.read()
    if success:
        # Run YOLOv8 inference on the frame
        results = model(frame, verbose=False)
                
        # Visualize the results on the frame
        # annotated_frame = results[0].plot(line_width = 1, labels = False)
        annotated_frame = frame
        
        # Draw bounding box and center
        check_cls = [[0 for _ in range(10)] for _ in range(10)]
        raw_coordinates = [0] * 135
        
        for det in results[0].boxes:
            # det: [x1, y1, x2, y2, conf, cls]
            xy = det.xyxy.tolist()[0]
            conf, cls = det.conf.item(), int(det.cls.item())
            # cls definition
            # 0: fore / 1: hind / 2: nose / 3: head / 4: ass / 5: tail / 6: torso

            # Calculate the center of the bounding box
            center_x, center_y = (int(xy[0]) + int(xy[2])) // 2, (int(xy[1]) + int(xy[3])) // 2
            
            # Get only one xy pair (highest conf value) in each camera view
            for i in range(5):
                # Find the ROI (camera 0 to 4)
                if(center_x > area[i][0] and center_x < area[i][2] and center_y > area[i][1] and center_y < area[i][3]):
                    # forehand
                    if(cls == 0 or cls == 1): # 0: fore / 1: hind
                        if(check_cls[i][rearrange[cls]] == 0):
                            raw_coordinates[i*27 + rearrange[cls]*3] = center_x
                            raw_coordinates[i*27 + 1 + rearrange[cls]*3] = center_y
                            raw_coordinates[i*27 + 2 + rearrange[cls]*3] = conf
                            check_cls[i][rearrange[cls]] += 1
                        elif(check_cls[i][rearrange[cls]] == 1):
                            raw_coordinates[i*27 + rearrange[cls]*3 + 3] = center_x
                            raw_coordinates[i*27 + 1 + rearrange[cls]*3 + 3] = center_y
                            raw_coordinates[i*27 + 2 + rearrange[cls]*3 + 3] = conf
                            check_cls[i][rearrange[cls]] += 1
                    elif(check_cls[i][rearrange[cls]] == 0): # Rest of body points
                        raw_coordinates[i*27 + rearrange[cls]*3] = center_x
                        raw_coordinates[i*27 + 1 + rearrange[cls]*3] = center_y
                        raw_coordinates[i*27 + 2 + rearrange[cls]*3] = conf
                        check_cls[i][rearrange[cls]] += 1

            # Optionally draw the bounding box
            # cv2.rectangle(annotated_frame, (int(xy[0]), int(xy[1])), (int(xy[2]), int(xy[3])), color=(255, 0, 0), thickness=2)
        
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        break
    
    # If feature is not detected, bring a previous value
    if(current_frame>0):
        for i in range(135):
            if(raw_coordinates[i] == 0):
                raw_coordinates[i] = output[current_frame-1][i]

    # Measure an angle of each limb from body-ass line (4, 5: forelimb / 6, 7: hindlimb / 2: body / 3: ass)

    # forelimb (54 is for bottom camera)
    f1_angle = sp.get_AB_AC_angle(raw_coordinates[54 + 3*3], raw_coordinates[54 + 3*3 +1],
                               raw_coordinates[54 + 2*3], raw_coordinates[54 + 2*3 +1],
                               raw_coordinates[54 + 4*3], raw_coordinates[54 + 4*3 +1])

    f2_angle = sp.get_AB_AC_angle(raw_coordinates[54 + 3*3], raw_coordinates[54 + 3*3 +1],
                               raw_coordinates[54 + 2*3], raw_coordinates[54 + 2*3 +1],
                               raw_coordinates[54 + 5*3], raw_coordinates[54 + 5*3 +1])
    
    if(f1_angle < 180 and f2_angle > 180):        
        temp = raw_coordinates[54 + 4*3 : 54 + 4*3 +2]
        raw_coordinates[54 + 4*3: 54 + 4*3 +2] = raw_coordinates[54 +5*3 : 54 +5*3 +2]
        raw_coordinates[54 + 5*3 : 54+ 5*3 +2] = temp
    
    # hindlimb
    h1_angle = sp.get_AB_AC_angle(raw_coordinates[54 + 3*3], raw_coordinates[54 + 3*3+1],
                               raw_coordinates[54 + 2*3], raw_coordinates[54 + 2*3+1],
                               raw_coordinates[54 + 6*3], raw_coordinates[54 + 6*3+1])

    h2_angle = sp.get_AB_AC_angle(raw_coordinates[54 + 3*3], raw_coordinates[54 + 3*3+1],
                                   raw_coordinates[54 + 2*3], raw_coordinates[54 + 2*3+1],
                                   raw_coordinates[54 + 7*3], raw_coordinates[54 + 7*3+1])
    
    if(h1_angle < 180 and h2_angle > 180):
        temp = raw_coordinates[54 + 6*3 : 54 + 6*3+2]
        raw_coordinates[54 + 6*3 : 54 + 6*3+2] = raw_coordinates[54 +7*3 : 54 + 7*3+2]
        raw_coordinates[54 + 7*3 : 54 + 7*3+2] = temp

    # Draw a center point of each feature
    for i in range(5):
        for j in range(9):
            if(raw_coordinates[i*27+j*3] != 0):
                cv2.circle(annotated_frame, (raw_coordinates[i*27+j*3], raw_coordinates[i*27+j*3+1]),
                        radius=10, color=color_code[color_order[j]], thickness=-1)

    # Display the frame with bounding box and center
    # resized_frame = cv2.resize(annotated_frame, (800, 600))
    # out.write(annotated_frame)
    # cv2.imshow("YOLOv8 Inference", resized_frame)

    # Write the annotated frame to the output video file
    out.write(annotated_frame)
    
    # Result accumulation
    output.append(raw_coordinates)
    
    # Print total estimated time
    sp.print_remaining_time(start_time, time.time()-start_time, current_frame, frame_total)
    
    current_frame += 1

# Print job completion
if(current_frame == frame_total):
    print('\r', flush=True) # Make sure the blank
    print("Pose estimation complete!", end='\r', flush=True)

# Save to txt file
with open(file_path+file_name+'.txt', 'w') as file:
    for row in output:
        file.write('\t'.join(map(str, row)) + '\n')

cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 208 of 209 frames processed: 0.00 mins left
# Pose estimation complete!
